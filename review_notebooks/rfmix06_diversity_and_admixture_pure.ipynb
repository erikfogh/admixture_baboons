# %%
# %run ../scripts/notebook_settings_lean.py
from scipy import stats
from horizonplot import horizonplot
from chromwindow import window
import zarr
import allel
pd.options.display.float_format = '{:10,.3g}'.format #

# %% [markdown]
# A repeat of rfmix14, now with an addendum wherein I compare the Tanzania results with the close references in Serengeti/Mikumi.

# %%
c_r_g_df = pd.read_csv("../steps/rfmix_stats_df/call_recomb_genes.txt")
c_r_g_df
# Out:
#       chrom      start  callable_frac        end         cM     end_cM  \
# 0      chr1          0          0.795     100000          0       0.36
# 1      chr1     100000           0.89     200000       0.36      0.477
# 2      chr1     200000          0.919     300000      0.477      0.547
# 3      chr1     300000          0.878     400000      0.547      0.626
# 4      chr1     400000          0.485     500000      0.626       1.37
# ...     ...        ...            ...        ...        ...        ...
# 27377  chrX  143200000           0.67  143300000        127        127
# 27378  chrX  143300000          0.905  143400000        127        127
# 27379  chrX  143400000          0.789  143500000        127        127
# 27380  chrX  143500000          0.836  143600000        127        127
# 27381  chrX  143600000          0.604  143691566        127        127
#
#        average_cM_window                                              genes  \
# 0                3.6e-06  ['RNF223', 'C1H1orf159', 'C1H1orf159', 'C1H1or...
# 1               1.16e-06  ['TTLL10', 'TTLL10', 'TTLL10', 'TTLL10', 'TTLL...
# 2               7.05e-07  ['B3GALT6', 'C1QTNF12', 'UBE2J2', 'UBE2J2', 'U...
# 3               7.94e-07  ['DVL1', 'DVL1', 'DVL1', 'MXRA8', 'MXRA8', 'MX...
# 4                7.4e-06                       ['VWA1', 'TMEM240', 'SSU72']
# ...                  ...                                                ...
# 27377           2.56e-07      ['TMLHE', 'TMLHE', 'TMLHE', 'TMLHE', 'TMLHE']
# 27378           3.37e-07               ['TMLHE', 'TMLHE', 'TMLHE', 'TMLHE']
# 27379            2.8e-07                                          ['SPRY3']
# 27380           7.53e-07                                          ['VAMP7']
# 27381           3.69e-06                                          ['VAMP7']
#
#        genic
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ...      ...
# 27377   True
# 27378   True
# 27379   True
# 27380   True
# 27381   True
#
# [27382 rows x 9 columns]

# %% [markdown]
# Section on outgroup diversity

# %%
zarr_chrX_dir = "/home/eriks/baboondiversity/data/PG_panu3_zarr_12_03_2021/callset.zarr/chrX"
#Opening the zarr data
callset_f = zarr.open_group(zarr_chrX_dir, mode="r")
gt_f = allel.GenotypeArray(callset_f["calldata/GT"])
pos_f = callset_f["variants/POS"][:]

zarr_all_chrX_dir = "/home/eriks/baboondiversity/data/PG_panu3_zarr_12_03_2021/callset.zarr/all_chrX"
#Opening the zarr data
callset_all_chrX = zarr.open_group(zarr_all_chrX_dir, mode="r")
gt_all_chrX = allel.GenotypeArray(callset_all_chrX["calldata/GT"])
pos_all_chrX = callset_all_chrX["variants/POS"][:]

zarr_dipmale_chrX = "/home/eriks/baboondiversity/data/PG_panu3_zarr_12_03_2021/callset.zarr/dipmale_chrX"
#Opening the zarr data
callset_dipmale_chrX = zarr.open_group(zarr_dipmale_chrX, mode="r")

meta_data_samples_sci = pd.read_csv("../data/Papio_metadata_with_clustering_sci.txt", sep =" ")
meta_data_samples = pd.read_csv("../data/Papio_metadata_with_clustering.txt", sep =" ")

#Generate a mapping between metadata and callset - repeat for chrX females to be sure of no errors.
ID_to_callset_f = dict(zip(callset_f["samples"][:], range(len(callset_f["samples"][:]))))
meta_data_samples_f = meta_data_samples_sci.loc[meta_data_samples_sci.PGDP_ID.isin(callset_f["samples"][:])].copy()
meta_data_samples_f["callset_index"] = meta_data_samples_f.PGDP_ID.map(ID_to_callset_f)

ID_to_callset_dip = dict(zip(callset_dipmale_chrX["samples"][:], range(len(callset_dipmale_chrX["samples"][:]))))
meta_data_samples_dip = meta_data_samples_sci.loc[meta_data_samples_sci.PGDP_ID.isin(callset_dipmale_chrX["samples"][:])].copy()
meta_data_samples_dip["callset_index"] = meta_data_samples_dip.PGDP_ID.map(ID_to_callset_dip)

# %%
rfmix_path = "../steps/rfmix_gen100/eth_olive_focus_plain/"
df_l = []
chroms = ["chr{}".format(x) for x in (range(1, 21))]+["all_chrX"]
for c in chroms:
    read_file = rfmix_path + "{}.windows.txt".format(c)
    df = pd.read_csv(read_file, sep="\t")
    df_l.append(df)
window_df_eth = pd.concat(df_l)
mean_window_df_eth = window_df_eth.groupby(["chrom", "individual", "start", "end"]).mean().reset_index()

# %%
rfmix_path = "../steps/rfmix_gen100/tanzania_pure_focus_plain/"

df_l = []
chroms = ["chr{}".format(x) for x in (range(1, 21))]+["all_chrX"]
for c in chroms:
    read_file = rfmix_path + "{}.windows.txt".format(c)
    df = pd.read_csv(read_file, sep="\t")
    df_l.append(df)
window_df_tanz = pd.concat(df_l)
mean_window_df_tanz = window_df_tanz.groupby(["chrom", "individual", "start", "end"]).mean().reset_index()
tanz_olives = meta_data_samples_sci.loc[meta_data_samples_sci.C_origin == "Anubis, Tanzania"].PGDP_ID
mean_window_df_tanz_olive = mean_window_df_tanz.loc[mean_window_df_tanz.individual.isin(tanz_olives)]

# %%
meta_data_samples.Origin.unique()
# Out:
# array(['Mikumi, Tanzania', 'Aberdare, Kenya', 'Chunga, Zambia', 'captive',
#        'Awash, Ethiopia', 'Serengeti, Tanzania', 'Arusha, Tanzania',
#        'Ngorongoro, Tanzania', 'Ruaha, Tanzania', 'Gombe, Tanzania',
#        'Udzungwa, Tanzania', 'Mahale, Tanzania', 'Katavi, Tanzania',
#        'Selous, Tanzania', 'Lake Manyara, Tanzania',
#        'Tarangire, Tanzania', 'Niokolo-Koba, Senegal',
#        'Issa Valley, Tanzania', 'Dendro Park, Zambia', 'Filoha, Ethiopia',
#        'Gog Woreda, Gambella region, Ethiopia'], dtype=object)

# %%
focus_pop_tags = ["Chunga, Zambia", "Dendro Park, Zambia", "Niokolo-Koba, Senegal", "Filoha, Ethiopia"]
window_size = 100000
all_chroms = ["chr{}".format(x) for x in (range(1, 21))]+["chrX"]

c_df_l = []
for c in all_chroms:
    print(c)
    zarr_dir = "/home/eriks/baboondiversity/data/PG_panu3_zarr_12_03_2021/callset.zarr/" + c
    #Opening the zarr data
    callset = zarr.open_group(zarr_dir, mode="r")
    gt = allel.GenotypeArray(callset["calldata/GT"])
    pos = callset["variants/POS"][:]
    # Loading in the IDs and gt
    df_l = []
    for p in focus_pop_tags:
        if c == "chrX":
            metadata = meta_data_samples_f
            focus_pop_gt = gt.take(metadata.loc[(metadata.Origin == p) &
                                            (metadata.Sex == "F")].callset_index,
                       axis=1)
        else:
            metadata = meta_data_samples
            focus_pop_gt = gt.take(metadata.loc[metadata.Origin == p].callset_index,
                       axis=1)
        pi, windows, n_bases, counts = allel.windowed_diversity(pos, focus_pop_gt.count_alleles(),
                          size=window_size, start=0)
        df_l.append(pd.DataFrame({"chrom": c, "population": p, "start": windows[:,0], "diversity": pi}))
    focus_df = pd.concat(df_l)
    if c == "chrX":
        rf_c = "female_chrX"
    elif c == "dipmale_chrX":
        rf_c = "all_chrX"
    else:
        rf_c = c
    print(c, rf_c)
    c_df_l.append(focus_df)
# Out:
# chr1
# chr1 chr1
# chr2
# chr2 chr2
# chr3
# chr3 chr3
# chr4
# chr4 chr4
# chr5
# chr5 chr5
# chr6
# chr6 chr6
# chr7
# chr7 chr7
# chr8
# chr8 chr8
# chr9
# chr9 chr9
# chr10
# chr10 chr10
# chr11
# chr11 chr11
# chr12
# chr12 chr12
# chr13
# chr13 chr13
# chr14
# chr14 chr14
# chr15
# chr15 chr15
# chr16
# chr16 chr16
# chr17
# chr17 chr17
# chr18
# chr18 chr18
# chr19
# chr19 chr19
# chr20
# chr20 chr20
# chrX
# chrX female_chrX

# %%
diversity_df = pd.concat(c_df_l)
mean_diversity = diversity_df.groupby(["chrom", "start"])[["diversity"]].mean().reset_index()
mean_diversity
# Out:
#       chrom      start  diversity
# 0      chr1          0    0.00306
# 1      chr1     100000    0.00191
# 2      chr1     200000    0.00115
# 3      chr1     300000   0.000888
# 4      chr1     400000    0.00453
# ...     ...        ...        ...
# 27377  chrX  143200000   0.000105
# 27378  chrX  143300000   0.000204
# 27379  chrX  143400000   0.000151
# 27380  chrX  143500000   0.000134
# 27381  chrX  143600000   0.000798
#
# [27382 rows x 3 columns]

# %% [markdown]
# I split based on origin.

# %%
window_df_tanz["Origin"] = window_df_tanz.individual.map(dict(zip(meta_data_samples_sci.PGDP_ID, meta_data_samples_sci.Origin)))

# %%
window_df_eth["Origin"] = window_df_eth.individual.map(dict(zip(meta_data_samples_sci.PGDP_ID, meta_data_samples_sci.Origin+"_eth_case")))

# %%
window_df_tanz_eth = pd.concat([window_df_tanz, window_df_eth])

# %%
mean_window_df_tanz_eth = window_df_tanz_eth.groupby(["chrom", "Origin", "start", "end"])[["north_sum"]].mean().reset_index()
mean_window_df_tanz = window_df_tanz.groupby(["chrom", "Origin", "start", "end"])[["north_sum"]].mean().reset_index()
admix_div_mean = mean_diversity.merge(mean_window_df_tanz_eth, on=["chrom", "start"])
admix_div_mean["Species"] = admix_div_mean.Origin.map(dict(zip(meta_data_samples_sci.Origin, meta_data_samples_sci.Species)))
admix_div_mean = admix_div_mean.merge(c_r_g_df, on=["chrom", "start"])
admix_div_mean = admix_div_mean.loc[admix_div_mean.chrom != "all_chrX"]
admix_div_mean["North Percentage"] = admix_div_mean.north_sum/100000
admix_div_mean["logdiv"] = np.log10(admix_div_mean.diversity)
admix_div_mean["logrecomb"] = np.log10(admix_div_mean.average_cM_window)
admix_div_mean["norm_diversity"] = (admix_div_mean.diversity-admix_div_mean.diversity.mean())/admix_div_mean.diversity.std()
admix_div_mean["norm_recomb"] = (admix_div_mean.average_cM_window-admix_div_mean.average_cM_window.mean())/admix_div_mean.average_cM_window.std()

# %%
#Selecting the cases of interest and setting Minor Parent Ancestry
origins_interest = ['Arusha, Tanzania',
       'Gog Woreda, Gambella region, Ethiopia_eth_case',
       'Gombe, Tanzania', 'Issa Valley, Tanzania',
       'Katavi, Tanzania','Lake Manyara, Tanzania',
       'Ngorongoro, Tanzania', 'Ruaha, Tanzania',
       'Selous, Tanzania', 'Serengeti, Tanzania', 'Tarangire, Tanzania',
       'Udzungwa, Tanzania']
admix_div_mean = admix_div_mean.loc[admix_div_mean.Origin.isin(origins_interest)]
admix_div_mean["minor_parent_percentage"] = [x if y == ("cynocephalus") or z == "Gog Woreda, Gambella region, Ethiopia_eth_case"
                                             else 1-x for x, y, z in zip(admix_div_mean["North Percentage"],
                                                                         admix_div_mean["Species"],
                                                                        admix_div_mean["Origin"])]
admix_div_mean["local_minor_ancestry"] = [min(x, 1-x) for x in admix_div_mean["North Percentage"]]

# %%
yellows = ['Katavi, Tanzania', 'Ruaha, Tanzania', 'Selous, Tanzania', 'Udzungwa, Tanzania']
olives = ['Serengeti, Tanzania', 'Ngorongoro, Tanzania', 'Gombe, Tanzania',
          'Lake Manyara, Tanzania','Arusha, Tanzania']
olives_with_tarangire = ['Serengeti, Tanzania', 'Tarangire, Tanzania', 'Ngorongoro, Tanzania', 'Gombe, Tanzania',
          'Lake Manyara, Tanzania','Arusha, Tanzania']
gog = ['Gog Woreda, Ethiopia']
result_order = ['Selous, Tanzania', 'Udzungwa, Tanzania', 'Katavi, Tanzania', 'Ruaha, Tanzania',
       'Tarangire, Tanzania', 'Arusha, Tanzania', 'Ngorongoro, Tanzania', 'Gombe, Tanzania', 
             'Lake Manyara, Tanzania', 'Serengeti, Tanzania']
result_order_no_gog = ['Selous, Tanzania', 'Udzungwa, Tanzania', 'Katavi, Tanzania', 'Ruaha, Tanzania',
       'Tarangire, Tanzania', 'Arusha, Tanzania', 'Ngorongoro, Tanzania', 'Gombe, Tanzania', 
             'Lake Manyara, Tanzania', 'Serengeti, Tanzania']

# %%
import copy
from textwrap import dedent
import warnings
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

try:
    import statsmodels
    assert statsmodels
    _has_statsmodels = True
except ImportError:
    _has_statsmodels = False

from seaborn import utils
from seaborn import algorithms as algo
from seaborn.axisgrid import FacetGrid, _facet_docs


__all__ = ["lmplot", "regplot", "residplot"]


class _LinearPlotter:
    """Base class for plotting relational data in tidy format.

    To get anything useful done you'll have to inherit from this, but setup
    code that can be abstracted out should be put here.

    """
    def establish_variables(self, data, **kws):
        """Extract variables from data or use directly."""
        self.data = data

        # Validate the inputs
        any_strings = any([isinstance(v, str) for v in kws.values()])
        if any_strings and data is None:
            raise ValueError("Must pass `data` if using named variables.")

        # Set the variables
        for var, val in kws.items():
            if isinstance(val, str):
                vector = data[val]
            elif isinstance(val, list):
                vector = np.asarray(val)
            else:
                vector = val
            if vector is not None and vector.shape != (1,):
                vector = np.squeeze(vector)
            if np.ndim(vector) > 1:
                err = "regplot inputs must be 1d"
                raise ValueError(err)
            setattr(self, var, vector)

    def dropna(self, *vars):
        """Remove observations with missing data."""
        vals = [getattr(self, var) for var in vars]
        vals = [v for v in vals if v is not None]
        not_na = np.all(np.column_stack([pd.notnull(v) for v in vals]), axis=1)
        for var in vars:
            val = getattr(self, var)
            if val is not None:
                setattr(self, var, val[not_na])

    def plot(self, ax):
        raise NotImplementedError


class _RegressionPlotter(_LinearPlotter):
    """Plotter for numeric independent variables with regression model.

    This does the computations and drawing for the `regplot` function, and
    is thus also used indirectly by `lmplot`.
    """
    def __init__(self, x, y, data=None, x_estimator=None, x_bins=None,
                 x_ci="ci", scatter=True, fit_reg=True, ci=95, n_boot=1000,
                 units=None, seed=None, order=1, logistic=False, lowess=False,
                 robust=False, weighted=False, logx=False, x_partial=None, y_partial=None,
                 truncate=False, dropna=True, x_jitter=None, y_jitter=None,
                 color=None, label=None):

        # Set member attributes
        self.x_estimator = x_estimator
        self.ci = ci
        self.x_ci = ci if x_ci == "ci" else x_ci
        self.n_boot = n_boot
        self.seed = seed
        self.scatter = scatter
        self.fit_reg = fit_reg
        self.order = order
        self.logistic = logistic
        self.weighted = weighted
        self.lowess = lowess
        self.robust = robust
        self.logx = logx
        self.truncate = truncate
        self.x_jitter = x_jitter
        self.y_jitter = y_jitter
        self.color = color
        self.label = label

        # Validate the regression options:
        #if sum((order > 1, logistic, robust, weighted, lowess, logx)) > 1:
        #    raise ValueError("Mutually exclusive regression options.")

        # Extract the data vals from the arguments or passed dataframe
        self.establish_variables(data, x=x, y=y, units=units,
                                 x_partial=x_partial, y_partial=y_partial)

        # Drop null observations
        if dropna:
            self.dropna("x", "y", "units", "x_partial", "y_partial")

        # Regress nuisance variables out of the data
        if self.x_partial is not None:
            self.x = self.regress_out(self.x, self.x_partial)
        if self.y_partial is not None:
            self.y = self.regress_out(self.y, self.y_partial)

        # Possibly bin the predictor variable, which implies a point estimate
        if x_bins is not None:
            self.x_estimator = np.mean if x_estimator is None else x_estimator
            x_discrete, x_bins = self.bin_predictor(x_bins)
            self.x_discrete = x_discrete
        else:
            self.x_discrete = self.x

        # Disable regression in case of singleton inputs
        if len(self.x) <= 1:
            self.fit_reg = False

        # Save the range of the x variable for the grid later
        if self.fit_reg:
            self.x_range = self.x.min(), self.x.max()

    @property
    def scatter_data(self):
        """Data where each observation is a point."""
        x_j = self.x_jitter
        if x_j is None:
            x = self.x
        else:
            x = self.x + np.random.uniform(-x_j, x_j, len(self.x))

        y_j = self.y_jitter
        if y_j is None:
            y = self.y
        else:
            y = self.y + np.random.uniform(-y_j, y_j, len(self.y))

        return x, y

    @property
    def estimate_data(self):
        """Data with a point estimate and CI for each discrete x value."""
        x, y = self.x_discrete, self.y
        vals = sorted(np.unique(x))
        points, cis = [], []

        for val in vals:

            # Get the point estimate of the y variable
            _y = y[x == val]
            est = self.x_estimator(_y)
            points.append(est)

            # Compute the confidence interval for this estimate
            if self.x_ci is None:
                cis.append(None)
            else:
                units = None
                if self.x_ci == "sd":
                    sd = np.std(_y)
                    _ci = est - sd, est + sd
                else:
                    if self.units is not None:
                        units = self.units[x == val]
                    boots = algo.bootstrap(_y,
                                           func=self.x_estimator,
                                           n_boot=self.n_boot,
                                           units=units,
                                           seed=self.seed)
                    _ci = utils.ci(boots, self.x_ci)
                cis.append(_ci)

        return vals, points, cis

    def _check_statsmodels(self):
        """Check whether statsmodels is installed if any boolean options require it."""
        options = "logistic", "robust", "lowess"
        err = "`{}=True` requires statsmodels, an optional dependency, to be installed."
        for option in options:
            if getattr(self, option) and not _has_statsmodels:
                raise RuntimeError(err.format(option))

    def fit_regression(self, ax=None, x_range=None, grid=None):
        """Fit the regression model."""
        self._check_statsmodels()

        # Create the grid for the regression
        if grid is None:
            if self.truncate:
                x_min, x_max = self.x_range
            else:
                if ax is None:
                    x_min, x_max = x_range
                else:
                    x_min, x_max = ax.get_xlim()
            grid = np.linspace(x_min, x_max, 100)
        ci = self.ci

        # Fit the regression
        if self.order > 1:
            yhat, yhat_boots = self.fit_poly(grid, self.order)
        elif self.logistic: 
            from statsmodels.genmod.generalized_linear_model import GLM
            from statsmodels.genmod.families import Binomial
            yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
                                                    family=Binomial())
        elif self.weighted: 
            from statsmodels.genmod.generalized_linear_model import GLM
            from statsmodels.genmod.families import Binomial
            yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
                                                   var_weights=np.asarray(self.x))
        elif self.lowess:
            ci = None
            grid, yhat = self.fit_lowess()
        elif self.robust:
            from statsmodels.robust.robust_linear_model import RLM
            yhat, yhat_boots = self.fit_statsmodels(grid, RLM)
        elif self.logx:
            yhat, yhat_boots = self.fit_logx(grid)
        else:
            yhat, yhat_boots = self.fit_fast(grid)

        # Compute the confidence interval at each grid point
        if ci is None:
            err_bands = None
        else:
            err_bands = utils.ci(yhat_boots, ci, axis=0)

        return grid, yhat, err_bands

    def fit_fast(self, grid):
        """Low-level regression and prediction using linear algebra."""
        def reg_func(_x, _y):
            return np.linalg.pinv(_x).dot(_y)

        X, y = np.c_[np.ones(len(self.x)), self.x], self.y
        grid = np.c_[np.ones(len(grid)), grid]
        yhat = grid.dot(reg_func(X, y))
        if self.ci is None:
            return yhat, None

        beta_boots = algo.bootstrap(X, y,
                                    func=reg_func,
                                    n_boot=self.n_boot,
                                    units=self.units,
                                    seed=self.seed).T
        yhat_boots = grid.dot(beta_boots).T
        return yhat, yhat_boots

    def fit_poly(self, grid, order):
        """Regression using numpy polyfit for higher-order trends."""
        def reg_func(_x, _y):
            return np.polyval(np.polyfit(_x, _y, order), grid)

        x, y = self.x, self.y
        yhat = reg_func(x, y)
        if self.ci is None:
            return yhat, None

        yhat_boots = algo.bootstrap(x, y,
                                    func=reg_func,
                                    n_boot=self.n_boot,
                                    units=self.units,
                                    seed=self.seed)
        return yhat, yhat_boots

    def fit_statsmodels(self, grid, model, **kwargs):
        """More general regression function using statsmodels objects."""
        import statsmodels.tools.sm_exceptions as sme
        X, y = np.c_[np.ones(len(self.x)), self.x], self.y
        grid = np.c_[np.ones(len(grid)), grid]
        def reg_func(_x, _y, **kwargs):
            err_classes = (sme.PerfectSeparationError,)
            try:
                with warnings.catch_warnings():
                    if hasattr(sme, "PerfectSeparationWarning"):
                        # statsmodels>=0.14.0
                        warnings.simplefilter("error", sme.PerfectSeparationWarning)
                        err_classes = (*err_classes, sme.PerfectSeparationWarning)
                    m = model(_y, _x, var_weights=np.asarray(_x[:, 1])).fit()
                    yhat = m.predict(grid)
                    #print(m.summary(), self.x, len(_x), _x[:, 1])
            except err_classes:
                yhat = np.empty(len(grid))
                yhat.fill(np.nan)
            return yhat

        yhat = reg_func(X, y, **kwargs)
        if self.ci is None:
            return yhat, None

        yhat_boots = bootstrap(X, y,
                                    func=reg_func,
                                    n_boot=self.n_boot,
                                    units=self.units,
                                    seed=self.seed,
                                   var_weights=np.asarray(self.x))
        return yhat, yhat_boots

    def fit_lowess(self):
        """Fit a locally-weighted regression, which returns its own grid."""
        from statsmodels.nonparametric.smoothers_lowess import lowess
        grid, yhat = lowess(self.y, self.x).T
        return grid, yhat

    def fit_logx(self, grid):
        """Fit the model in log-space."""
        X, y = np.c_[np.ones(len(self.x)), self.x], self.y
        grid = np.c_[np.ones(len(grid)), np.log(grid)]

        def reg_func(_x, _y):
            _x = np.c_[_x[:, 0], np.log(_x[:, 1])]
            return np.linalg.pinv(_x).dot(_y)

        yhat = grid.dot(reg_func(X, y))
        if self.ci is None:
            return yhat, None

        beta_boots = algo.bootstrap(X, y,
                                    func=reg_func,
                                    n_boot=self.n_boot,
                                    units=self.units,
                                    seed=self.seed).T
        yhat_boots = grid.dot(beta_boots).T
        return yhat, yhat_boots

    def bin_predictor(self, bins):
        """Discretize a predictor by assigning value to closest bin."""
        x = np.asarray(self.x)
        if np.isscalar(bins):
            percentiles = np.linspace(0, 100, bins + 2)[1:-1]
            bins = np.percentile(x, percentiles)
        else:
            bins = np.ravel(bins)

        dist = np.abs(np.subtract.outer(x, bins))
        x_binned = bins[np.argmin(dist, axis=1)].ravel()

        return x_binned, bins

    def regress_out(self, a, b):
        """Regress b from a keeping a's original mean."""
        a_mean = a.mean()
        a = a - a_mean
        b = b - b.mean()
        b = np.c_[b]
        a_prime = a - b.dot(np.linalg.pinv(b).dot(a))
        return np.asarray(a_prime + a_mean).reshape(a.shape)

    def plot(self, ax, scatter_kws, line_kws):
        """Draw the full plot."""
        # Insert the plot label into the correct set of keyword arguments
        if self.scatter:
            scatter_kws["label"] = self.label
        else:
            line_kws["label"] = self.label

        # Use the current color cycle state as a default
        if self.color is None:
            lines, = ax.plot([], [])
            color = lines.get_color()
            lines.remove()
        else:
            color = self.color

        # Ensure that color is hex to avoid matplotlib weirdness
        color = mpl.colors.rgb2hex(mpl.colors.colorConverter.to_rgb(color))

        # Let color in keyword arguments override overall plot color
        scatter_kws.setdefault("color", color)
        line_kws.setdefault("color", color)

        # Draw the constituent plots
        if self.scatter:
            self.scatterplot(ax, scatter_kws)

        if self.fit_reg:
            self.lineplot(ax, line_kws)

        # Label the axes
        if hasattr(self.x, "name"):
            ax.set_xlabel(self.x.name)
        if hasattr(self.y, "name"):
            ax.set_ylabel(self.y.name)

    def scatterplot(self, ax, kws):
        """Draw the data."""
        # Treat the line-based markers specially, explicitly setting larger
        # linewidth than is provided by the seaborn style defaults.
        # This would ideally be handled better in matplotlib (i.e., distinguish
        # between edgewidth for solid glyphs and linewidth for line glyphs
        # but this should do for now.
        line_markers = ["1", "2", "3", "4", "+", "x", "|", "_"]
        if self.x_estimator is None:
            if "marker" in kws and kws["marker"] in line_markers:
                lw = mpl.rcParams["lines.linewidth"]
            else:
                lw = mpl.rcParams["lines.markeredgewidth"]
            kws.setdefault("linewidths", lw)

            if not hasattr(kws['color'], 'shape') or kws['color'].shape[1] < 4:
                kws.setdefault("alpha", .8)

            x, y = self.scatter_data
            ax.scatter(x, y, **kws)
        else:
            # TODO abstraction
            ci_kws = {"color": kws["color"]}
            if "alpha" in kws:
                ci_kws["alpha"] = kws["alpha"]
            ci_kws["linewidth"] = mpl.rcParams["lines.linewidth"] * 1.75
            kws.setdefault("s", 50)

            xs, ys, cis = self.estimate_data
            if [ci for ci in cis if ci is not None]:
                for x, ci in zip(xs, cis):
                    ax.plot([x, x], ci, **ci_kws)
            ax.scatter(xs, ys, **kws)

    def lineplot(self, ax, kws):
        """Draw the model."""
        # Fit the regression model
        grid, yhat, err_bands = self.fit_regression(ax)
        edges = grid[0], grid[-1]

        # Get set default aesthetics
        fill_color = kws["color"]
        lw = kws.pop("lw", mpl.rcParams["lines.linewidth"] * 1.5)
        kws.setdefault("linewidth", lw)

        # Draw the regression line and confidence interval
        line, = ax.plot(grid, yhat, **kws)
        if not self.truncate:
            line.sticky_edges.x[:] = edges  # Prevent mpl from adding margin
        if err_bands is not None:
            ax.fill_between(grid, *err_bands, facecolor=fill_color, alpha=.15)


_regression_docs = dict(

    model_api=dedent("""\
    There are a number of mutually exclusive options for estimating the
    regression model. See the :ref:`tutorial <regression_tutorial>` for more
    information.\
    """),
    regplot_vs_lmplot=dedent("""\
    The :func:`regplot` and :func:`lmplot` functions are closely related, but
    the former is an axes-level function while the latter is a figure-level
    function that combines :func:`regplot` and :class:`FacetGrid`.\
    """),
    x_estimator=dedent("""\
    x_estimator : callable that maps vector -> scalar, optional
        Apply this function to each unique value of ``x`` and plot the
        resulting estimate. This is useful when ``x`` is a discrete variable.
        If ``x_ci`` is given, this estimate will be bootstrapped and a
        confidence interval will be drawn.\
    """),
    x_bins=dedent("""\
    x_bins : int or vector, optional
        Bin the ``x`` variable into discrete bins and then estimate the central
        tendency and a confidence interval. This binning only influences how
        the scatterplot is drawn; the regression is still fit to the original
        data.  This parameter is interpreted either as the number of
        evenly-sized (not necessary spaced) bins or the positions of the bin
        centers. When this parameter is used, it implies that the default of
        ``x_estimator`` is ``numpy.mean``.\
    """),
    x_ci=dedent("""\
    x_ci : "ci", "sd", int in [0, 100] or None, optional
        Size of the confidence interval used when plotting a central tendency
        for discrete values of ``x``. If ``"ci"``, defer to the value of the
        ``ci`` parameter. If ``"sd"``, skip bootstrapping and show the
        standard deviation of the observations in each bin.\
    """),
    scatter=dedent("""\
    scatter : bool, optional
        If ``True``, draw a scatterplot with the underlying observations (or
        the ``x_estimator`` values).\
    """),
    fit_reg=dedent("""\
    fit_reg : bool, optional
        If ``True``, estimate and plot a regression model relating the ``x``
        and ``y`` variables.\
    """),
    ci=dedent("""\
    ci : int in [0, 100] or None, optional
        Size of the confidence interval for the regression estimate. This will
        be drawn using translucent bands around the regression line. The
        confidence interval is estimated using a bootstrap; for large
        datasets, it may be advisable to avoid that computation by setting
        this parameter to None.\
    """),
    n_boot=dedent("""\
    n_boot : int, optional
        Number of bootstrap resamples used to estimate the ``ci``. The default
        value attempts to balance time and stability; you may want to increase
        this value for "final" versions of plots.\
    """),
    units=dedent("""\
    units : variable name in ``data``, optional
        If the ``x`` and ``y`` observations are nested within sampling units,
        those can be specified here. This will be taken into account when
        computing the confidence intervals by performing a multilevel bootstrap
        that resamples both units and observations (within unit). This does not
        otherwise influence how the regression is estimated or drawn.\
    """),
    seed=dedent("""\
    seed : int, numpy.random.Generator, or numpy.random.RandomState, optional
        Seed or random number generator for reproducible bootstrapping.\
    """),
    order=dedent("""\
    order : int, optional
        If ``order`` is greater than 1, use ``numpy.polyfit`` to estimate a
        polynomial regression.\
    """),
    logistic=dedent("""\
    logistic : bool, optional
        If ``True``, assume that ``y`` is a binary variable and use
        ``statsmodels`` to estimate a logistic regression model. Note that this
        is substantially more computationally intensive than linear regression,
        so you may wish to decrease the number of bootstrap resamples
        (``n_boot``) or set ``ci`` to None.\
    """),
    lowess=dedent("""\
    lowess : bool, optional
        If ``True``, use ``statsmodels`` to estimate a nonparametric lowess
        model (locally weighted linear regression). Note that confidence
        intervals cannot currently be drawn for this kind of model.\
    """),
    robust=dedent("""\
    robust : bool, optional
        If ``True``, use ``statsmodels`` to estimate a robust regression. This
        will de-weight outliers. Note that this is substantially more
        computationally intensive than standard linear regression, so you may
        wish to decrease the number of bootstrap resamples (``n_boot``) or set
        ``ci`` to None.\
    """),
    logx=dedent("""\
    logx : bool, optional
        If ``True``, estimate a linear regression of the form y ~ log(x), but
        plot the scatterplot and regression model in the input space. Note that
        ``x`` must be positive for this to work.\
    """),
    xy_partial=dedent("""\
    {x,y}_partial : strings in ``data`` or matrices
        Confounding variables to regress out of the ``x`` or ``y`` variables
        before plotting.\
    """),
    truncate=dedent("""\
    truncate : bool, optional
        If ``True``, the regression line is bounded by the data limits. If
        ``False``, it extends to the ``x`` axis limits.
    """),
    dropna=dedent("""\
    dropna : bool, optional
        If ``True``, remove observations with missing data from the plot.
    """),
    xy_jitter=dedent("""\
    {x,y}_jitter : floats, optional
        Add uniform random noise of this size to either the ``x`` or ``y``
        variables. The noise is added to a copy of the data after fitting the
        regression, and only influences the look of the scatterplot. This can
        be helpful when plotting variables that take discrete values.\
    """),
    scatter_line_kws=dedent("""\
    {scatter,line}_kws : dictionaries
        Additional keyword arguments to pass to ``plt.scatter`` and
        ``plt.plot``.\
    """),
)
_regression_docs.update(_facet_docs)


def lmplot(
    data, *,
    x=None, y=None, hue=None, col=None, row=None,
    palette=None, col_wrap=None, height=5, aspect=1, markers="o",
    sharex=None, sharey=None, hue_order=None, col_order=None, row_order=None,
    legend=True, legend_out=None, x_estimator=None, x_bins=None,
    x_ci="ci", scatter=True, fit_reg=True, ci=95, n_boot=1000,
    units=None, seed=None, order=1, logistic=False, lowess=False,
    robust=False, weighted=False, logx=False, x_partial=None, y_partial=None,
    truncate=True, x_jitter=None, y_jitter=None, scatter_kws=None,
    line_kws=None, facet_kws=None,
):

    if facet_kws is None:
        facet_kws = {}

    def facet_kw_deprecation(key, val):
        msg = (
            f"{key} is deprecated from the `lmplot` function signature. "
            "Please update your code to pass it using `facet_kws`."
        )
        if val is not None:
            warnings.warn(msg, UserWarning)
            facet_kws[key] = val

    facet_kw_deprecation("sharex", sharex)
    facet_kw_deprecation("sharey", sharey)
    facet_kw_deprecation("legend_out", legend_out)

    if data is None:
        raise TypeError("Missing required keyword argument `data`.")

    # Reduce the dataframe to only needed columns
    need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
    cols = np.unique([a for a in need_cols if a is not None]).tolist()
    data = data[cols]

    # Initialize the grid
    facets = FacetGrid(
        data, row=row, col=col, hue=hue,
        palette=palette,
        row_order=row_order, col_order=col_order, hue_order=hue_order,
        height=height, aspect=aspect, col_wrap=col_wrap,
        **facet_kws,
    )

    # Add the markers here as FacetGrid has figured out how many levels of the
    # hue variable are needed and we don't want to duplicate that process
    if facets.hue_names is None:
        n_markers = 1
    else:
        n_markers = len(facets.hue_names)
    if not isinstance(markers, list):
        markers = [markers] * n_markers
    if len(markers) != n_markers:
        raise ValueError("markers must be a singleton or a list of markers "
                         "for each level of the hue variable")
    facets.hue_kws = {"marker": markers}

    #def update_datalim(data, x, y, ax, **kws):
    #    xys = data[[x, y]].to_numpy().astype(float)
    #    ax.update_datalim(xys, updatey=False)
    #    ax.autoscale_view(scaley=False)

    #facets.map_dataframe(update_datalim, x=x, y=y)

    # Draw the regression plot on each facet
    regplot_kws = dict(
        x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
        scatter=scatter, fit_reg=fit_reg, ci=ci, n_boot=n_boot, units=units,
        seed=seed, order=order, logistic=logistic, lowess=lowess,
        robust=robust, weighted=weighted, logx=logx, x_partial=x_partial, y_partial=y_partial,
        truncate=truncate, x_jitter=x_jitter, y_jitter=y_jitter,
        scatter_kws=scatter_kws, line_kws=line_kws,
    )
    facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
    facets.set_axis_labels(x, y)

    # Add a legend
    if legend and (hue is not None) and (hue not in [col, row]):
        facets.add_legend()
    return facets


lmplot.__doc__ = dedent("""\
    Plot data and regression model fits across a FacetGrid.

    This function combines :func:`regplot` and :class:`FacetGrid`. It is
    intended as a convenient interface to fit regression models across
    conditional subsets of a dataset.

    When thinking about how to assign variables to different facets, a general
    rule is that it makes sense to use ``hue`` for the most important
    comparison, followed by ``col`` and ``row``. However, always think about
    your particular dataset and the goals of the visualization you are
    creating.

    {model_api}

    The parameters to this function span most of the options in
    :class:`FacetGrid`, although there may be occasional cases where you will
    want to use that class and :func:`regplot` directly.

    Parameters
    ----------
    {data}
    x, y : strings, optional
        Input variables; these should be column names in ``data``.
    hue, col, row : strings
        Variables that define subsets of the data, which will be drawn on
        separate facets in the grid. See the ``*_order`` parameters to control
        the order of levels of this variable.
    {palette}
    {col_wrap}
    {height}
    {aspect}
    markers : matplotlib marker code or list of marker codes, optional
        Markers for the scatterplot. If a list, each marker in the list will be
        used for each level of the ``hue`` variable.
    {share_xy}

        .. deprecated:: 0.12.0
            Pass using the `facet_kws` dictionary.

    {{hue,col,row}}_order : lists, optional
        Order for the levels of the faceting variables. By default, this will
        be the order that the levels appear in ``data`` or, if the variables
        are pandas categoricals, the category order.
    legend : bool, optional
        If ``True`` and there is a ``hue`` variable, add a legend.
    {legend_out}

        .. deprecated:: 0.12.0
            Pass using the `facet_kws` dictionary.

    {x_estimator}
    {x_bins}
    {x_ci}
    {scatter}
    {fit_reg}
    {ci}
    {n_boot}
    {units}
    {seed}
    {order}
    {logistic}
    {lowess}
    {robust}
    {logx}
    {xy_partial}
    {truncate}
    {xy_jitter}
    {scatter_line_kws}
    facet_kws : dict
        Dictionary of keyword arguments for :class:`FacetGrid`.

    Returns
    -------
    :class:`FacetGrid`
        The :class:`FacetGrid` object with the plot on it for further tweaking.

    See Also
    --------
    regplot : Plot data and a conditional model fit.
    FacetGrid : Subplot grid for plotting conditional relationships.
    pairplot : Combine :func:`regplot` and :class:`PairGrid` (when used with
               ``kind="reg"``).

    Notes
    -----

    {regplot_vs_lmplot}

    Examples
    --------

    .. include:: ../docstrings/lmplot.rst

    """).format(**_regression_docs)


def regplot(
    data=None, *, x=None, y=None,
    x_estimator=None, x_bins=None, x_ci="ci",
    scatter=True, fit_reg=True, ci=95, n_boot=1000, units=None,
    seed=None, order=1, logistic=False, lowess=False, robust=False, weighted=False,
    logx=False, x_partial=None, y_partial=None,
    truncate=True, dropna=True, x_jitter=None, y_jitter=None,
    label=None, color=None, marker="o",
    scatter_kws=None, line_kws=None, ax=None
):

    plotter = _RegressionPlotter(x, y, data, x_estimator, x_bins, x_ci,
                                 scatter, fit_reg, ci, n_boot, units, seed,
                                 order, logistic, lowess, robust, weighted, logx,
                                 x_partial, y_partial, truncate, dropna,
                                 x_jitter, y_jitter, color, label)

    if ax is None:
        ax = plt.gca()

    scatter_kws = {} if scatter_kws is None else copy.copy(scatter_kws)
    scatter_kws["marker"] = marker
    line_kws = {} if line_kws is None else copy.copy(line_kws)
    plotter.plot(ax, scatter_kws, line_kws)
    return ax


regplot.__doc__ = dedent("""\
    Plot data and a linear regression model fit.

    {model_api}

    Parameters
    ----------
    x, y : string, series, or vector array
        Input variables. If strings, these should correspond with column names
        in ``data``. When pandas objects are used, axes will be labeled with
        the series name.
    {data}
    {x_estimator}
    {x_bins}
    {x_ci}
    {scatter}
    {fit_reg}
    {ci}
    {n_boot}
    {units}
    {seed}
    {order}
    {logistic}
    {lowess}
    {robust}
    {logx}
    {xy_partial}
    {truncate}
    {dropna}
    {xy_jitter}
    label : string
        Label to apply to either the scatterplot or regression line (if
        ``scatter`` is ``False``) for use in a legend.
    color : matplotlib color
        Color to apply to all plot elements; will be superseded by colors
        passed in ``scatter_kws`` or ``line_kws``.
    marker : matplotlib marker code
        Marker to use for the scatterplot glyphs.
    {scatter_line_kws}
    ax : matplotlib Axes, optional
        Axes object to draw the plot onto, otherwise uses the current Axes.

    Returns
    -------
    ax : matplotlib Axes
        The Axes object containing the plot.

    See Also
    --------
    lmplot : Combine :func:`regplot` and :class:`FacetGrid` to plot multiple
             linear relationships in a dataset.
    jointplot : Combine :func:`regplot` and :class:`JointGrid` (when used with
                ``kind="reg"``).
    pairplot : Combine :func:`regplot` and :class:`PairGrid` (when used with
               ``kind="reg"``).
    residplot : Plot the residuals of a linear regression model.

    Notes
    -----

    {regplot_vs_lmplot}


    It's also easy to combine :func:`regplot` and :class:`JointGrid` or
    :class:`PairGrid` through the :func:`jointplot` and :func:`pairplot`
    functions, although these do not directly accept all of :func:`regplot`'s
    parameters.

    Examples
    --------

    .. include:: ../docstrings/regplot.rst

    """).format(**_regression_docs)


def bootstrap(*args, **kwargs):
    """Resample one or more arrays with replacement and store aggregate values.

    Positional arguments are a sequence of arrays to bootstrap along the first
    axis and pass to a summary function.

    Keyword arguments:
        n_boot : int, default=10000
            Number of iterations
        axis : int, default=None
            Will pass axis to ``func`` as a keyword argument.
        units : array, default=None
            Array of sampling unit IDs. When used the bootstrap resamples units
            and then observations within units instead of individual
            datapoints.
        func : string or callable, default="mean"
            Function to call on the args that are passed in. If string, uses as
            name of function in the numpy namespace. If nans are present in the
            data, will try to use nan-aware version of named function.
        seed : Generator | SeedSequence | RandomState | int | None
            Seed for the random number generator; useful if you want
            reproducible resamples.

    Returns
    -------
    boot_dist: array
        array of bootstrapped statistic values

    """
    # Ensure list of arrays are same length
    if len(np.unique(list(map(len, args)))) > 1:
        raise ValueError("All input arrays must have the same length")
    n = len(args[0])

    # Default keyword arguments
    n_boot = kwargs.get("n_boot", 10000)
    func = kwargs.get("func", "mean")
    axis = kwargs.get("axis", None)
    units = kwargs.get("units", None)
    var_weights = kwargs.get("var_weights", None)
    random_seed = kwargs.get("random_seed", None)
    if random_seed is not None:
        msg = "`random_seed` has been renamed to `seed` and will be removed"
        warnings.warn(msg)
    seed = kwargs.get("seed", random_seed)
    if axis is None:
        func_kwargs = dict()
    else:
        func_kwargs = dict(axis=axis)

    # Initialize the resampler
    if isinstance(seed, np.random.RandomState):
        rng = seed
    else:
        rng = np.random.default_rng(seed)

    # Coerce to arrays
    args = list(map(np.asarray, args))
    if units is not None:
        units = np.asarray(units)

    if isinstance(func, str):

        # Allow named numpy functions
        f = getattr(np, func)

        # Try to use nan-aware version of function if necessary
        missing_data = np.isnan(np.sum(np.column_stack(args)))

        if missing_data and not func.startswith("nan"):
            nanf = getattr(np, f"nan{func}", None)
            if nanf is None:
                msg = f"Data contain nans but no nan-aware version of `{func}` found"
                warnings.warn(msg, UserWarning)
            else:
                f = nanf

    else:
        f = func

    # Handle numpy changes
    try:
        integers = rng.integers
    except AttributeError:
        integers = rng.randint


    boot_dist = []
    for i in range(int(n_boot)):
        resampler = integers(0, n, n, dtype=np.intp)  # intp is indexing dtype
        sample = [a.take(resampler, axis=0) for a in args]
        boot_dist.append(f(*sample, **func_kwargs))
    return np.array(boot_dist)

# %%
filter_callable = admix_div_mean.loc[admix_div_mean.callable_frac > 0.75]
filter_callable.loc[filter_callable['Origin'] == 'Gog Woreda, Gambella region, Ethiopia_eth_case', ['Origin']] = 'Gog Woreda, Ethiopia'
filter_callable["diversity"].quantile([0.005, 0.995])
# Out:
# 0.005     0.000513
# 0.995      0.00408
# Name: diversity, dtype: float64

# %%
len(filter_callable)/len(admix_div_mean)
# Out:
# 0.9890152245133937

# %%
filter_callable = admix_div_mean.loc[admix_div_mean.callable_frac > 0.75]
filter_callable.loc[filter_callable['Origin'] == 'Gog Woreda, Gambella region, Ethiopia_eth_case', ['Origin']] = 'Gog Woreda, Ethiopia'
filter_qcut = filter_callable.loc[(filter_callable.diversity >= 0.000513) &
                                 (filter_callable.diversity <= 0.00408)]

# %%
o_l, stat_l, pval_l = [], [], []
for o in result_order:
    o_div = filter_callable.loc[filter_callable.Origin == o]
    o_div = o_div.loc[(o_div.minor_parent_percentage < 0.5)]
    st, pval = stats.spearmanr(o_div.diversity, o_div["minor_parent_percentage"])
    print(o, stats.spearmanr(o_div.diversity, o_div["minor_parent_percentage"]))
    o_l.append(o), stat_l.append(st), pval_l.append(pval)
# Out:
# Selous, Tanzania SignificanceResult(statistic=0.000912705144504937, pvalue=0.8837660606216835)
# Udzungwa, Tanzania SignificanceResult(statistic=0.06311021352476846, pvalue=4.5661910537064916e-24)
# Katavi, Tanzania SignificanceResult(statistic=0.045705449726932704, pvalue=4.158464940555877e-13)
# Ruaha, Tanzania SignificanceResult(statistic=0.04147666644598282, pvalue=3.2413469620002423e-11)
# Tarangire, Tanzania SignificanceResult(statistic=-0.02314350422567235, pvalue=0.0004120740270596824)
# Arusha, Tanzania SignificanceResult(statistic=0.013252054318467729, pvalue=0.03620208867465488)
# Ngorongoro, Tanzania SignificanceResult(statistic=0.03142508071750824, pvalue=5.796659058629138e-07)
# Gombe, Tanzania SignificanceResult(statistic=0.061854489412457254, pvalue=8.899004428266695e-23)
# Lake Manyara, Tanzania SignificanceResult(statistic=0.025544911625458383, pvalue=4.556948330794172e-05)
# Serengeti, Tanzania SignificanceResult(statistic=0.02151771954511404, pvalue=0.0005745878923575679)

# %%
pd.DataFrame({"Origin": o_l, "Statistic": stat_l, "P-Value": pval_l})
# Out:
#                    Origin  Statistic    P-Value
# 0        Selous, Tanzania   0.000913      0.884
# 1      Udzungwa, Tanzania     0.0631   4.57e-24
# 2        Katavi, Tanzania     0.0457   4.16e-13
# 3         Ruaha, Tanzania     0.0415   3.24e-11
# 4     Tarangire, Tanzania    -0.0231   0.000412
# 5        Arusha, Tanzania     0.0133     0.0362
# 6    Ngorongoro, Tanzania     0.0314    5.8e-07
# 7         Gombe, Tanzania     0.0619    8.9e-23
# 8  Lake Manyara, Tanzania     0.0255   4.56e-05
# 9     Serengeti, Tanzania     0.0215   0.000575

# %%
import statsmodels.formula.api as smf

o_l, slope_l, intercept_l, rval_l, pval_l, stderr_l = [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut.loc[filter_qcut.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=o_div).fit()
    print(o, glm_results.summary())
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00025273
# Method:                               IRLS   Log-Likelihood:                 69173.
# Date:                     Mon, 20 Jul 2026   Deviance:                       6.4203
# Time:                             11:04:21   Pearson chi2:                     6.42
# No. Iterations:                          3   Pseudo R-squ. (CS):          7.510e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0020      0.000      6.473      0.000       0.001       0.003
# diversity     -0.2350      0.170     -1.381      0.167      -0.568       0.098
# ==============================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012426
# Method:                               IRLS   Log-Likelihood:                 48941.
# Date:                     Mon, 20 Jul 2026   Deviance:                       31.568
# Time:                             11:04:21   Pearson chi2:                     31.6
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001546
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0064      0.001      9.357      0.000       0.005       0.008
# diversity      2.3650      0.377      6.270      0.000       1.626       3.104
# ==============================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.015379
# Method:                               IRLS   Log-Likelihood:                 16983.
# Date:                     Mon, 20 Jul 2026   Deviance:                       390.69
# Time:                             11:04:21   Pearson chi2:                     391.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0006207
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0570      0.002     23.741      0.000       0.052       0.062
# diversity      5.2700      1.327      3.972      0.000       2.669       7.871
# ==============================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0089904
# Method:                               IRLS   Log-Likelihood:                 23803.
# Date:                     Mon, 20 Jul 2026   Deviance:                       228.39
# Time:                             11:04:22   Pearson chi2:                     228.
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001545
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0651      0.002     35.462      0.000       0.062       0.069
# diversity      6.3579      1.015      6.267      0.000       4.369       8.346
# ==============================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.030040
# Method:                               IRLS   Log-Likelihood:                 8478.3
# Date:                     Mon, 20 Jul 2026   Deviance:                       763.14
# Time:                             11:04:22   Pearson chi2:                     763.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0002028
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2330      0.003     69.434      0.000       0.226       0.240
# diversity     -4.2099      1.855     -2.270      0.023      -7.845      -0.575
# ==============================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.019082
# Method:                               IRLS   Log-Likelihood:                 14242.
# Date:                     Mon, 20 Jul 2026   Deviance:                       484.77
# Time:                             11:04:22   Pearson chi2:                     485.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0002679
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0942      0.003     35.234      0.000       0.089       0.099
# diversity     -3.8567      1.478     -2.609      0.009      -6.754      -0.960
# ==============================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.013968
# Method:                               IRLS   Log-Likelihood:                 18206.
# Date:                     Mon, 20 Jul 2026   Deviance:                       354.85
# Time:                             11:04:22   Pearson chi2:                     355.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0001124
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0642      0.002     28.071      0.000       0.060       0.069
# diversity      2.1371      1.265      1.690      0.091      -0.341       4.616
# ==============================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.015157
# Method:                               IRLS   Log-Likelihood:                 17168.
# Date:                     Mon, 20 Jul 2026   Deviance:                       385.05
# Time:                             11:04:22   Pearson chi2:                     385.
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001951
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0604      0.002     25.357      0.000       0.056       0.065
# diversity      9.2784      1.317      7.043      0.000       6.697      11.860
# ==============================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0093870
# Method:                               IRLS   Log-Likelihood:                 23254.
# Date:                     Mon, 20 Jul 2026   Deviance:                       238.47
# Time:                             11:04:22   Pearson chi2:                     238.
# No. Iterations:                          3   Pseudo R-squ. (CS):          1.980e-07
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0664      0.002     35.380      0.000       0.063       0.070
# diversity      0.0730      1.037      0.070      0.944      -1.959       2.105
# ==============================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0059189
# Method:                               IRLS   Log-Likelihood:                 29113.
# Date:                     Mon, 20 Jul 2026   Deviance:                       150.36
# Time:                             11:04:22   Pearson chi2:                     150.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0001204
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0437      0.001     29.306      0.000       0.041       0.047
# diversity      1.4397      0.823      1.749      0.080      -0.174       3.053
# ==============================================================================

# %%
import statsmodels.api as sm
import numpy as np

df_l = []
for o in result_order:
    o_div = filter_qcut.loc[filter_qcut.Origin == o]
    o_div = o_div.loc[(o_div.callable_frac > 0.75)]
    Y = o_div["minor_parent_percentage"]
    X = o_div.diversity
    X = sm.add_constant(X)
    model = sm.OLS(Y,X)
    results = model.fit()
    print(o)
    #print(results.t_test([1, 0]))
    het_test = sm.stats.het_breuschpagan(resid=results.resid, exog_het=X)
    print(het_test)
    #print(sm.stats.diagnostic.linear_harvey_collier(results))
    df_l.append(list(het_test))
bp_df = pd.DataFrame(df_l, columns=["Lagrange Multiplier", "Lagrange Multiplier P-value", "F-statistic", "F-statistic P-value"])
bp_df["Origin"] = result_order
bp_df
# Out:
# Selous, Tanzania
# (4.325845203758495, 0.03753776743620323, 4.326241289711374, 0.03753903317341705)
# Udzungwa, Tanzania
# (8.767746226706064, 0.0030660407556408354, 8.770082618360163, 0.003064947714814561)
# Katavi, Tanzania
# (2.601639786984439, 0.1067532100963064, 2.601701402756581, 0.10676148136599155)
# Ruaha, Tanzania
# (11.54730489272564, 0.0006784753616517463, 11.55164622040913, 0.0006779324044668604)
# Tarangire, Tanzania
# (2.679530136056753, 0.10164571511840804, 2.6796018125729066, 0.10165352645374096)
# Arusha, Tanzania
# (12.489682986958215, 0.0004092056280682608, 12.494842290005908, 0.0004088024138505052)
# Ngorongoro, Tanzania
# (0.19691629697601565, 0.6572215210557706, 0.19690232156322052, 0.6572366865990091)
# Gombe, Tanzania
# (16.168978063052595, 5.793517616476378e-05, 16.178001277713292, 5.7826521836052246e-05)
# Lake Manyara, Tanzania
# (1.7888104911397757, 0.18107115992476913, 1.7887956204545108, 0.18108494744219022)
# Serengeti, Tanzania
# (4.510037634471133, 0.03369649929922547, 4.510483291957912, 0.03369735586058122)
#    Lagrange Multiplier  Lagrange Multiplier P-value  F-statistic  \
# 0                 4.33                       0.0375         4.33
# 1                 8.77                      0.00307         8.77
# 2                  2.6                        0.107          2.6
# 3                 11.5                     0.000678         11.6
# 4                 2.68                        0.102         2.68
# 5                 12.5                     0.000409         12.5
# 6                0.197                        0.657        0.197
# 7                 16.2                     5.79e-05         16.2
# 8                 1.79                        0.181         1.79
# 9                 4.51                       0.0337         4.51
#
#    F-statistic P-value                  Origin
# 0               0.0375        Selous, Tanzania
# 1              0.00306      Udzungwa, Tanzania
# 2                0.107        Katavi, Tanzania
# 3             0.000678         Ruaha, Tanzania
# 4                0.102     Tarangire, Tanzania
# 5             0.000409        Arusha, Tanzania
# 6                0.657    Ngorongoro, Tanzania
# 7             5.78e-05         Gombe, Tanzania
# 8                0.181  Lake Manyara, Tanzania
# 9               0.0337     Serengeti, Tanzania

# %%
filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
g = sns.FacetGrid(filter_qcut.loc[filter_qcut.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 4, col_order=result_order_no_gog)
g.map_dataframe(sns.pointplot, y="minor_parent_percentage", x="Diversity Quantile", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Diversity Quantile", ylabel="Minor Parent Ancestry")
# Out:
# /tmp/50076219/ipykernel_3073965/2401538422.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,

# %%
o_l, low_l, high_l, effect_l, effect_hl_l = [], [], [], [], []
filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
for o in result_order:
    s_df = filter_qcut.loc[filter_qcut.Origin == o]
    #print(o, s_df.groupby(["Diversity Quantile"])[["minor_parent_percentage"]].mean())
    low_mean = s_df.loc[s_df["Diversity Quantile"] == "0-20"][["minor_parent_percentage"]].mean()[0]*100
    high_mean = s_df.loc[s_df["Diversity Quantile"] == "80-100"][["minor_parent_percentage"]].mean()[0]*100
    o_l.append(o)
    low_l.append(low_mean)
    high_l.append(high_mean)
    effect_l.append(high_mean/low_mean-1)
# Out:
# /tmp/50076219/ipykernel_3073965/4242712310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,

# %%
mean_quantile_df = pd.DataFrame({"Origin": o_l, "0-20 Minor Parent Percentage": low_l, 
                        "80-100 Minor Parent Percentage": high_l, "Relative Increase": effect_l})
mean_quantile_df["Absolute Increase"] = mean_quantile_df["80-100 Minor Parent Percentage"]-mean_quantile_df["0-20 Minor Parent Percentage"]
mean_quantile_df
# Out:
#                    Origin  0-20 Minor Parent Percentage  \
# 0        Selous, Tanzania                         0.197
# 1      Udzungwa, Tanzania                         0.917
# 2        Katavi, Tanzania                          6.32
# 3         Ruaha, Tanzania                          7.17
# 4     Tarangire, Tanzania                            24
# 5        Arusha, Tanzania                          9.36
# 6    Ngorongoro, Tanzania                          7.32
# 7         Gombe, Tanzania                          7.48
# 8  Lake Manyara, Tanzania                          7.16
# 9     Serengeti, Tanzania                          4.93
#
#    80-100 Minor Parent Percentage  Relative Increase  Absolute Increase
# 0                            0.15             -0.239            -0.0473
# 1                            1.29              0.409              0.375
# 2                            7.25              0.146              0.925
# 3                            8.25               0.15               1.08
# 4                              23            -0.0425              -1.02
# 5                            8.82            -0.0578             -0.541
# 6                            7.41             0.0133             0.0976
# 7                            8.86              0.185               1.38
# 8                            7.06            -0.0145             -0.104
# 9                            4.97            0.00793             0.0391

# %%
o_l, low_l, high_l, effect_l, effect_hl_l = [], [], [], [], []
filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
for o in result_order:
    s_df = filter_qcut.loc[filter_qcut.Origin == o]
    #print(o, s_df.groupby(["Diversity Quantile"])[["minor_parent_percentage"]].mean())
    low_mean = s_df.loc[s_df["Diversity Quantile"] == "0-20"][["minor_parent_percentage"]].mean()[0]*100
    high_mean = s_df.loc[s_df["Diversity Quantile"] == "80-100"][["minor_parent_percentage"]].mean()[0]*100
    o_l.append(o)
    low_l.append(low_mean)
    high_l.append(high_mean)
    effect_l.append(high_mean/low_mean-1)
# Out:
# /tmp/50076219/ipykernel_3073965/4242712310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,

# %%
filter_qcut
# Out:
#        chrom      start  diversity                 Origin      end_x  \
# 2       chr1          0    0.00306       Arusha, Tanzania     100000
# 9       chr1          0    0.00306   Gog Woreda, Ethiopia     100000
# 10      chr1          0    0.00306        Gombe, Tanzania     100000
# 11      chr1          0    0.00306  Issa Valley, Tanzania     100000
# 13      chr1          0    0.00306       Katavi, Tanzania     100000
# ...      ...        ...        ...                    ...        ...
# 648594  chr9  125600000     0.0023        Ruaha, Tanzania  125700000
# 648595  chr9  125600000     0.0023       Selous, Tanzania  125700000
# 648596  chr9  125600000     0.0023    Serengeti, Tanzania  125700000
# 648597  chr9  125600000     0.0023    Tarangire, Tanzania  125700000
# 648598  chr9  125600000     0.0023     Udzungwa, Tanzania  125700000
#
#         north_sum       Species  callable_frac      end_y         cM  ...  \
# 2        9.98e+04        anubis          0.795     100000          0  ...
# 9        9.86e+04           NaN          0.795     100000          0  ...
# 10       8.81e+04        anubis          0.795     100000          0  ...
# 11       8.16e+04  cynocephalus          0.795     100000          0  ...
# 13       1.58e+04  cynocephalus          0.795     100000          0  ...
# ...           ...           ...            ...        ...        ...  ...
# 648594   2.19e+04  cynocephalus          0.869  125700000        115  ...
# 648595          0  cynocephalus          0.869  125700000        115  ...
# 648596      1e+05        anubis          0.869  125700000        115  ...
# 648597   6.61e+04        anubis          0.869  125700000        115  ...
# 648598          0  cynocephalus          0.869  125700000        115  ...
#
#                                                     genes  genic  \
# 2       ['RNF223', 'C1H1orf159', 'C1H1orf159', 'C1H1or...   True
# 9       ['RNF223', 'C1H1orf159', 'C1H1orf159', 'C1H1or...   True
# 10      ['RNF223', 'C1H1orf159', 'C1H1orf159', 'C1H1or...   True
# 11      ['RNF223', 'C1H1orf159', 'C1H1orf159', 'C1H1or...   True
# 13      ['RNF223', 'C1H1orf159', 'C1H1orf159', 'C1H1or...   True
# ...                                                   ...    ...
# 648594                                 ['SYCE1', 'SYCE1']   True
# 648595                                 ['SYCE1', 'SYCE1']   True
# 648596                                 ['SYCE1', 'SYCE1']   True
# 648597                                 ['SYCE1', 'SYCE1']   True
# 648598                                 ['SYCE1', 'SYCE1']   True
#
#        North Percentage     logdiv  logrecomb  norm_diversity  norm_recomb  \
# 2                 0.998      -2.51      -5.44            1.69         2.91
# 9                 0.986      -2.51      -5.44            1.69         2.91
# 10                0.881      -2.51      -5.44            1.69         2.91
# 11                0.816      -2.51      -5.44            1.69         2.91
# 13                0.158      -2.51      -5.44            1.69         2.91
# ...                 ...        ...        ...             ...          ...
# 648594            0.219      -2.64      -5.58           0.709         1.87
# 648595                0      -2.64      -5.58           0.709         1.87
# 648596                1      -2.64      -5.58           0.709         1.87
# 648597            0.661      -2.64      -5.58           0.709         1.87
# 648598                0      -2.64      -5.58           0.709         1.87
#
#         minor_parent_percentage  local_minor_ancestry  Diversity Quantile
# 2                        0.0016                0.0016              80-100
# 9                         0.986                0.0143              80-100
# 10                        0.119                 0.119              80-100
# 11                        0.816                 0.184              80-100
# 13                        0.158                 0.158              80-100
# ...                         ...                   ...                 ...
# 648594                    0.219                 0.219              80-100
# 648595                        0                     0              80-100
# 648596                        0                     0              80-100
# 648597                    0.339                 0.339              80-100
# 648598                        0                     0              80-100
#
# [304872 rows x 22 columns]

# %%
sns.lmplot(filter_qcut.loc[filter_qcut.Origin == "Gombe, Tanzania"].groupby(["chrom"])[["diversity", "minor_parent_percentage"]].mean(),
               x="diversity", y="minor_parent_percentage")

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_callable.loc[filter_callable.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=o_div).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00025151
# Method:                               IRLS   Log-Likelihood:                 69926.
# Date:                     Mon, 20 Jul 2026   Deviance:                       6.4533
# Time:                             11:04:26   Pearson chi2:                     6.45
# No. Iterations:                          3   Pseudo R-squ. (CS):          1.021e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0017      0.000      6.180      0.000       0.001       0.002
# diversity     -0.0769      0.150     -0.512      0.609      -0.371       0.218
# ==============================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012341
# Method:                               IRLS   Log-Likelihood:                 49518.
# Date:                     Mon, 20 Jul 2026   Deviance:                       31.666
# Time:                             11:04:26   Pearson chi2:                     31.7
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001246
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0071      0.001     11.582      0.000       0.006       0.008
# diversity      1.8827      0.333      5.656      0.000       1.230       2.535
# ==============================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.015351
# Method:                               IRLS   Log-Likelihood:                 17176.
# Date:                     Mon, 20 Jul 2026   Deviance:                       393.88
# Time:                             11:04:26   Pearson chi2:                     394.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0003940
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0594      0.002     27.428      0.000       0.055       0.064
# diversity      3.7334      1.174      3.180      0.001       1.432       6.034
# ==============================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0089818
# Method:                               IRLS   Log-Likelihood:                 24053.
# Date:                     Mon, 20 Jul 2026   Deviance:                       230.46
# Time:                             11:04:26   Pearson chi2:                     230.
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001395
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0667      0.002     40.243      0.000       0.063       0.070
# diversity      5.3754      0.898      5.986      0.000       3.615       7.136
# ==============================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.030062
# Method:                               IRLS   Log-Likelihood:                 8553.6
# Date:                     Mon, 20 Jul 2026   Deviance:                       771.33
# Time:                             11:04:26   Pearson chi2:                     771.
# No. Iterations:                          3   Pseudo R-squ. (CS):          6.353e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2297      0.003     75.736      0.000       0.224       0.236
# diversity     -2.0977      1.643     -1.277      0.202      -5.318       1.122
# ==============================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.019191
# Method:                               IRLS   Log-Likelihood:                 14312.
# Date:                     Mon, 20 Jul 2026   Deviance:                       492.39
# Time:                             11:04:26   Pearson chi2:                     492.
# No. Iterations:                          3   Pseudo R-squ. (CS):          8.073e-06
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0870      0.002     35.899      0.000       0.082       0.092
# diversity      0.5974      1.313      0.455      0.649      -1.975       3.170
# ==============================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.014074
# Method:                               IRLS   Log-Likelihood:                 18291.
# Date:                     Mon, 20 Jul 2026   Deviance:                       361.11
# Time:                             11:04:26   Pearson chi2:                     361.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0004906
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0613      0.002     29.549      0.000       0.057       0.065
# diversity      3.9891      1.124      3.549      0.000       1.786       6.192
# ==============================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                        0.015264
# Method:                               IRLS   Log-Likelihood:                 17250.
# Date:                     Mon, 20 Jul 2026   Deviance:                       391.64
# Time:                             11:04:26   Pearson chi2:                     392.
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.003095
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0586      0.002     27.137      0.000       0.054       0.063
# diversity     10.4417      1.171      8.919      0.000       8.147      12.736
# ==============================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0094708
# Method:                               IRLS   Log-Likelihood:                 23373.
# Date:                     Mon, 20 Jul 2026   Deviance:                       243.00
# Time:                             11:04:26   Pearson chi2:                     243.
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0002428
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0628      0.002     36.883      0.000       0.059       0.066
# diversity      2.3019      0.922      2.496      0.013       0.494       4.109
# ==============================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0060693
# Method:                               IRLS   Log-Likelihood:                 29082.
# Date:                     Mon, 20 Jul 2026   Deviance:                       155.73
# Time:                             11:04:26   Pearson chi2:                     156.
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001347
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0390      0.001     28.615      0.000       0.036       0.042
# diversity      4.3414      0.738      5.881      0.000       2.894       5.788
# ==============================================================================

# %%
filter_callable.Origin.unique()
# Out:
# array(['Arusha, Tanzania', 'Gog Woreda, Ethiopia', 'Gombe, Tanzania',
#        'Issa Valley, Tanzania', 'Katavi, Tanzania',
#        'Lake Manyara, Tanzania', 'Ngorongoro, Tanzania',
#        'Ruaha, Tanzania', 'Selous, Tanzania', 'Serengeti, Tanzania',
#        'Tarangire, Tanzania', 'Udzungwa, Tanzania'], dtype=object)

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df
# Out:
#                    Origin  Intercept      Slope  Intercept P-value  \
# 0        Selous, Tanzania    0.00171    -0.0769           6.39e-10
# 1      Udzungwa, Tanzania    0.00712       1.88           5.07e-31
# 2        Katavi, Tanzania     0.0594       3.73          1.28e-165
# 3         Ruaha, Tanzania     0.0667       5.38                  0
# 4     Tarangire, Tanzania       0.23       -2.1                  0
# 5        Arusha, Tanzania      0.087      0.597          3.19e-282
# 6    Ngorongoro, Tanzania     0.0613       3.99          6.82e-192
# 7         Gombe, Tanzania     0.0586       10.4           3.6e-162
# 8  Lake Manyara, Tanzania     0.0628        2.3          8.71e-298
# 9     Serengeti, Tanzania      0.039       4.34          4.36e-180
#
#    Slope P-value  Intercept stderr  Slope stderr
# 0          0.609          0.000277          0.15
# 1       1.55e-08          0.000615         0.333
# 2        0.00147           0.00217          1.17
# 3       2.16e-09           0.00166         0.898
# 4          0.202           0.00303          1.64
# 5          0.649           0.00242          1.31
# 6       0.000387           0.00208          1.12
# 7        4.7e-19           0.00216          1.17
# 8         0.0126            0.0017         0.922
# 9       4.08e-09           0.00136         0.738

# %%
filter_callable["diversity"].quantile([0.05, 0.95])
# Out:
# 0.05      0.00082
# 0.95       0.0028
# Name: diversity, dtype: float64

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_callable.loc[(filter_callable.Origin == o) #& (filter_callable.diversity <= 0.0028)
                               #& (filter_callable.diversity >= 0.000819)
                               ]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity",
                          data=o_div, var_weights=np.asarray(o_div["diversity"])
                         ).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      4.1993e-07
# Method:                               IRLS   Log-Likelihood:                 69458.
# Date:                     Mon, 20 Jul 2026   Deviance:                     0.010774
# Time:                             11:04:26   Pearson chi2:                   0.0108
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0003323
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0009      0.000      3.583      0.000       0.000       0.001
# diversity      0.3389      0.116      2.920      0.003       0.111       0.566
# ==============================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.1984e-06
# Method:                               IRLS   Log-Likelihood:                 48219.
# Date:                     Mon, 20 Jul 2026   Deviance:                     0.056406
# Time:                             11:04:26   Pearson chi2:                   0.0564
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0004941
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0090      0.001     15.731      0.000       0.008       0.010
# diversity      0.9457      0.266      3.561      0.000       0.425       1.466
# ==============================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.6646e-05
# Method:                               IRLS   Log-Likelihood:                 16209.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.68369
# Time:                             11:04:26   Pearson chi2:                    0.684
# No. Iterations:                          3   Pseudo R-squ. (CS):          3.316e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0651      0.002     32.816      0.000       0.061       0.069
# diversity      0.8528      0.925      0.922      0.356      -0.959       2.665
# ==============================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.5767e-05
# Method:                               IRLS   Log-Likelihood:                 22942.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.40455
# Time:                             11:04:26   Pearson chi2:                    0.405
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001125
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0698      0.002     45.705      0.000       0.067       0.073
# diversity      3.8218      0.711      5.374      0.000       2.428       5.216
# ==============================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      5.2482e-05
# Method:                               IRLS   Log-Likelihood:                 7513.0
# Date:                     Mon, 20 Jul 2026   Deviance:                       1.3466
# Time:                             11:04:26   Pearson chi2:                     1.35
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0005976
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2155      0.003     77.365      0.000       0.210       0.221
# diversity      5.0817      1.297      3.917      0.000       2.539       7.625
# ==============================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      3.2826e-05
# Method:                               IRLS   Log-Likelihood:                 13533.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.84225
# Time:                             11:04:26   Pearson chi2:                    0.842
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.003577
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0687      0.002     31.195      0.000       0.064       0.073
# diversity      9.8403      1.026      9.590      0.000       7.829      11.852
# ==============================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.4702e-05
# Method:                               IRLS   Log-Likelihood:                 17181.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.63382
# Time:                             11:04:26   Pearson chi2:                    0.634
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.004511
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0503      0.002     26.296      0.000       0.047       0.054
# diversity      9.5879      0.890     10.771      0.000       7.843      11.333
# ==============================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.7421e-05
# Method:                               IRLS   Log-Likelihood:                 15842.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.70357
# Time:                             11:04:26   Pearson chi2:                    0.704
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.009185
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0508      0.002     25.210      0.000       0.047       0.055
# diversity     14.4311      0.938     15.387      0.000      12.593      16.269
# ==============================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.6435e-05
# Method:                               IRLS   Log-Likelihood:                 22409.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.42170
# Time:                             11:04:26   Pearson chi2:                    0.422
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.004648
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0516      0.002     33.131      0.000       0.049       0.055
# diversity      7.9388      0.726     10.934      0.000       6.516       9.362
# ==============================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.1264e-05
# Method:                               IRLS   Log-Likelihood:                 27256.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.28901
# Time:                             11:04:26   Pearson chi2:                    0.289
# No. Iterations:                          3   Pseudo R-squ. (CS):            0.01299
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0258      0.001     20.002      0.000       0.023       0.028
# diversity     11.0119      0.601     18.320      0.000       9.834      12.190
# ==============================================================================

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df
# Out:
#                    Origin  Intercept      Slope  Intercept P-value  \
# 0        Selous, Tanzania   0.000893      0.339            0.00034
# 1      Udzungwa, Tanzania    0.00897      0.946           9.21e-56
# 2        Katavi, Tanzania     0.0651      0.853          3.52e-236
# 3         Ruaha, Tanzania     0.0698       3.82                  0
# 4     Tarangire, Tanzania      0.216       5.08                  0
# 5        Arusha, Tanzania     0.0687       9.84          1.25e-213
# 6    Ngorongoro, Tanzania     0.0503       9.59          2.15e-152
# 7         Gombe, Tanzania     0.0508       14.4          3.09e-140
# 8  Lake Manyara, Tanzania     0.0516       7.94          1.06e-240
# 9     Serengeti, Tanzania     0.0258         11           5.27e-89
#
#    Slope P-value  Intercept stderr  Slope stderr
# 0         0.0035          0.000249         0.116
# 1       0.000369           0.00057         0.266
# 2          0.356           0.00198         0.925
# 3        7.7e-08           0.00153         0.711
# 4       8.98e-05           0.00279           1.3
# 5       8.84e-22            0.0022          1.03
# 6       4.72e-27           0.00191          0.89
# 7       1.99e-53           0.00201         0.938
# 8       7.95e-28           0.00156         0.726
# 9       5.77e-75           0.00129         0.601

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut.loc[filter_qcut.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      4.1036e-07
# Method:                               IRLS   Log-Likelihood:                 69067.
# Date:                     Mon, 20 Jul 2026   Deviance:                     0.010425
# Time:                             11:04:26   Pearson chi2:                   0.0104
# No. Iterations:                          3   Pseudo R-squ. (CS):          6.189e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0019      0.000      6.015      0.000       0.001       0.003
# diversity     -0.2000      0.159     -1.254      0.210      -0.513       0.113
# ==============================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.1977e-06
# Method:                               IRLS   Log-Likelihood:                 47750.
# Date:                     Mon, 20 Jul 2026   Deviance:                     0.055831
# Time:                             11:04:26   Pearson chi2:                   0.0558
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001489
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0066      0.001      8.864      0.000       0.005       0.008
# diversity      2.2706      0.369      6.152      0.000       1.547       2.994
# ==============================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.6544e-05
# Method:                               IRLS   Log-Likelihood:                 16102.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.67432
# Time:                             11:04:26   Pearson chi2:                    0.674
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0009060
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0553      0.003     21.482      0.000       0.050       0.060
# diversity      6.1553      1.283      4.799      0.000       3.641       8.669
# ==============================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.5647e-05
# Method:                               IRLS   Log-Likelihood:                 22816.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.39750
# Time:                             11:04:26   Pearson chi2:                    0.398
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.002119
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0634      0.002     32.089      0.000       0.060       0.067
# diversity      7.2303      0.985      7.342      0.000       5.300       9.160
# ==============================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      5.1673e-05
# Method:                               IRLS   Log-Likelihood:                 7640.1
# Date:                     Mon, 20 Jul 2026   Deviance:                       1.3127
# Time:                             11:04:26   Pearson chi2:                     1.31
# No. Iterations:                          3   Pseudo R-squ. (CS):          5.776e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2208      0.004     61.466      0.000       0.214       0.228
# diversity      2.1678      1.790      1.211      0.226      -1.340       5.675
# ==============================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      3.1990e-05
# Method:                               IRLS   Log-Likelihood:                 13731.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.81267
# Time:                             11:04:26   Pearson chi2:                    0.813
# No. Iterations:                          3   Pseudo R-squ. (CS):          6.089e-06
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0879      0.003     31.105      0.000       0.082       0.093
# diversity     -0.5537      1.408     -0.393      0.694      -3.314       2.206
# ==============================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.3826e-05
# Method:                               IRLS   Log-Likelihood:                 17474.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.60527
# Time:                             11:04:27   Pearson chi2:                    0.605
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0009936
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0566      0.002     23.220      0.000       0.052       0.061
# diversity      6.1071      1.215      5.026      0.000       3.725       8.489
# ==============================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.6706e-05
# Method:                               IRLS   Log-Likelihood:                 16025.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.67844
# Time:                             11:04:27   Pearson chi2:                    0.678
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.003996
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0534      0.003     20.667      0.000       0.048       0.058
# diversity     12.9755      1.287     10.085      0.000      10.454      15.497
# ==============================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.5900e-05
# Method:                               IRLS   Log-Likelihood:                 22612.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.40392
# Time:                             11:04:27   Pearson chi2:                    0.404
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0006120
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0590      0.002     29.618      0.000       0.055       0.063
# diversity      3.9149      0.993      3.944      0.000       1.969       5.861
# ==============================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.0294e-05
# Method:                               IRLS   Log-Likelihood:                 28135.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.26150
# Time:                             11:04:27   Pearson chi2:                    0.262
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001202
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0380      0.002     23.676      0.000       0.035       0.041
# diversity      4.4155      0.799      5.528      0.000       2.850       5.981
# ==============================================================================

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df
# Out:
#                    Origin  Intercept      Slope  Intercept P-value  \
# 0        Selous, Tanzania    0.00193       -0.2            1.8e-09
# 1      Udzungwa, Tanzania    0.00657       2.27           7.74e-19
# 2        Katavi, Tanzania     0.0553       6.16          2.29e-102
# 3         Ruaha, Tanzania     0.0634       7.23          6.26e-226
# 4     Tarangire, Tanzania      0.221       2.17                  0
# 5        Arusha, Tanzania     0.0879     -0.554          2.07e-212
# 6    Ngorongoro, Tanzania     0.0566       6.11          2.84e-119
# 7         Gombe, Tanzania     0.0534         13           6.92e-95
# 8  Lake Manyara, Tanzania      0.059       3.91          8.85e-193
# 9     Serengeti, Tanzania      0.038       4.42           6.3e-124
#
#    Slope P-value  Intercept stderr  Slope stderr
# 0           0.21           0.00032         0.159
# 1       7.64e-10          0.000741         0.369
# 2        1.6e-06           0.00257          1.28
# 3       2.11e-13           0.00198         0.985
# 4          0.226           0.00359          1.79
# 5          0.694           0.00283          1.41
# 6       5.02e-07           0.00244          1.22
# 7       6.41e-24           0.00258          1.29
# 8       8.03e-05           0.00199         0.993
# 9       3.24e-08            0.0016         0.799

# %%
groups = filter_qcut.groupby("chrom")
aut_mean, chrom_mean = groups["diversity"].transform("mean"), filter_qcut["diversity"].mean()
filter_qcut["aut_norm_div"] = filter_qcut.diversity*chrom_mean/aut_mean
# Out:
# /tmp/50076219/ipykernel_3073965/3362829037.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut["aut_norm_div"] = filter_qcut.diversity*chrom_mean/aut_mean

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut.loc[filter_qcut.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ aut_norm_div", data=o_div,
                         var_weights=np.asarray(o_div["aut_norm_div"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      4.0893e-07
# Method:                               IRLS   Log-Likelihood:                 69135.
# Date:                     Mon, 20 Jul 2026   Deviance:                     0.010388
# Time:                             11:04:27   Pearson chi2:                   0.0104
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0001326
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0021      0.000      6.540      0.000       0.001       0.003
# aut_norm_div    -0.2944      0.160     -1.835      0.066      -0.609       0.020
# ================================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.2023e-06
# Method:                               IRLS   Log-Likelihood:                 47747.
# Date:                     Mon, 20 Jul 2026   Deviance:                     0.055946
# Time:                             11:04:27   Pearson chi2:                   0.0559
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001829
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0061      0.001      8.178      0.000       0.005       0.008
# aut_norm_div     2.5385      0.372      6.819      0.000       1.809       3.268
# ================================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.6390e-05
# Method:                               IRLS   Log-Likelihood:                 16199.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.67042
# Time:                             11:04:27   Pearson chi2:                    0.670
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0004699
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0582      0.003     22.566      0.000       0.053       0.063
# aut_norm_div     4.4530      1.289      3.456      0.001       1.927       6.979
# ================================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.5642e-05
# Method:                               IRLS   Log-Likelihood:                 22843.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.39737
# Time:                             11:04:27   Pearson chi2:                    0.397
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001921
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0640      0.002     32.231      0.000       0.060       0.068
# aut_norm_div     6.9332      0.992      6.989      0.000       4.989       8.878
# ================================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      5.1600e-05
# Method:                               IRLS   Log-Likelihood:                 7680.8
# Date:                     Mon, 20 Jul 2026   Deviance:                       1.3109
# Time:                             11:04:27   Pearson chi2:                     1.31
# No. Iterations:                          3   Pseudo R-squ. (CS):          1.883e-05
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.2225      0.004     61.698      0.000       0.215       0.230
# aut_norm_div     1.2462      1.802      0.692      0.489      -2.285       4.778
# ================================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      3.2027e-05
# Method:                               IRLS   Log-Likelihood:                 13740.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.81360
# Time:                             11:04:27   Pearson chi2:                    0.814
# No. Iterations:                          3   Pseudo R-squ. (CS):          4.709e-06
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0863      0.003     30.378      0.000       0.081       0.092
# aut_norm_div     0.4908      1.420      0.346      0.730      -2.291       3.273
# ================================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.3789e-05
# Method:                               IRLS   Log-Likelihood:                 17517.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.60433
# Time:                             11:04:27   Pearson chi2:                    0.604
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0006872
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0585      0.002     23.879      0.000       0.054       0.063
# aut_norm_div     5.1127      1.223      4.179      0.000       2.715       7.511
# ================================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      2.6754e-05
# Method:                               IRLS   Log-Likelihood:                 16025.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.67966
# Time:                             11:04:27   Pearson chi2:                    0.680
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.004230
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0525      0.003     20.214      0.000       0.047       0.058
# aut_norm_div    13.4643      1.297     10.378      0.000      10.921      16.007
# ================================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.5886e-05
# Method:                               IRLS   Log-Likelihood:                 22646.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.40357
# Time:                             11:04:27   Pearson chi2:                    0.404
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0006758
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0586      0.002     29.303      0.000       0.055       0.063
# aut_norm_div     4.1433      1.000      4.144      0.000       2.184       6.103
# ================================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.0282e-05
# Method:                               IRLS   Log-Likelihood:                 28173.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.26120
# Time:                             11:04:27   Pearson chi2:                    0.261
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001487
# Covariance Type:                 nonrobust
# ================================================================================
#                    coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        0.0371      0.002     23.047      0.000       0.034       0.040
# aut_norm_div     4.9458      0.804      6.149      0.000       3.369       6.522
# ================================================================================

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df
# Out:
#                    Origin  Intercept      Slope  Intercept P-value  \
# 0        Selous, Tanzania     0.0021     -0.294           6.14e-11
# 1      Udzungwa, Tanzania    0.00609       2.54           2.89e-16
# 2        Katavi, Tanzania     0.0582       4.45          9.39e-113
# 3         Ruaha, Tanzania      0.064       6.93          6.46e-228
# 4     Tarangire, Tanzania      0.222       1.25                  0
# 5        Arusha, Tanzania     0.0863      0.491          1.07e-202
# 6    Ngorongoro, Tanzania     0.0585       5.11          5.11e-126
# 7         Gombe, Tanzania     0.0525       13.5            7.4e-91
# 8  Lake Manyara, Tanzania     0.0586       4.14          9.57e-189
# 9     Serengeti, Tanzania     0.0371       4.95          1.58e-117
#
#    Slope P-value  Intercept stderr  Slope stderr
# 0         0.0665          0.000321          0.16
# 1       9.14e-12          0.000745         0.372
# 2       0.000549           0.00258          1.29
# 3       2.77e-12           0.00199         0.992
# 4          0.489           0.00361           1.8
# 5           0.73           0.00284          1.42
# 6       2.93e-05           0.00245          1.22
# 7       3.13e-25            0.0026           1.3
# 8       3.41e-05             0.002             1
# 9       7.79e-10           0.00161         0.804

# %%
o_div = filter_qcut.loc[filter_qcut.Origin.isin(["Mikumi, Tanzania", "Ruaha, Tanzania"])]
glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity*Origin", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
print(glm_results.summary(), glm_results.pvalues)
# Out:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25406
# Model:                                 GLM   Df Residuals:                    25404
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.5647e-05
# Method:                               IRLS   Log-Likelihood:                 22816.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.39750
# Time:                             11:04:27   Pearson chi2:                    0.398
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.002119
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0634      0.002     32.089      0.000       0.060       0.067
# diversity      7.2303      0.985      7.342      0.000       5.300       9.160
# ============================================================================== Intercept    6.26e-226
# diversity     2.11e-13
# dtype: float64

# %%
o_div = filter_qcut.loc[filter_qcut.Origin.isin(["Ngorongoro, Tanzania", "Tarangire, Tanzania"])]
glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity*Origin", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
print(glm_results.summary(), glm_results.pvalues)
# Out:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                50812
# Model:                                 GLM   Df Residuals:                    50808
# Model Family:                     Gaussian   Df Model:                            3
# Link Function:                    Identity   Scale:                      3.7749e-05
# Method:                               IRLS   Log-Likelihood:                 23257.
# Date:                     Mon, 20 Jul 2026   Deviance:                       1.9180
# Time:                             11:04:27   Pearson chi2:                     1.92
# No. Iterations:                          3   Pseudo R-squ. (CS):             0.2430
# Covariance Type:                 nonrobust
# ===========================================================================================================
#                                               coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# Intercept                                   0.0566      0.003     18.447      0.000       0.051       0.063
# Origin[T.Tarangire, Tanzania]               0.1642      0.004     37.806      0.000       0.156       0.173
# diversity                                   6.1071      1.530      3.993      0.000       3.109       9.105
# diversity:Origin[T.Tarangire, Tanzania]    -3.9393      2.163     -1.821      0.069      -8.179       0.301
# =========================================================================================================== Intercept                                   5.46e-76
# Origin[T.Tarangire, Tanzania]                      0
# diversity                                   6.54e-05
# diversity:Origin[T.Tarangire, Tanzania]       0.0686
# dtype: float64

# %%
from scipy.stats import norm

predictions = glm_results.get_prediction()
df_predictions = predictions.summary_frame()
df_predictions["diversity"] = o_div["diversity"]

# %%
g = sns.histplot(filter_qcut.loc[filter_qcut.Origin.isin(gog)], x="diversity")
g.set(xlabel = "Background Diversity")
g.set(xticks=np.arange(0.0005, 0.004, 0.001))
# Out:
# [[<matplotlib.axis.XTick at 0x1474b3e53160>,
#   <matplotlib.axis.XTick at 0x1474b3e53310>,
#   <matplotlib.axis.XTick at 0x1474b3eb9eb0>,
#   <matplotlib.axis.XTick at 0x1474b3dbf2b0>]]

# %%
g = sns.histplot(filter_callable.loc[filter_callable.Origin.isin(gog)], x="diversity")
g.set(xlabel = "Background Diversity")
#g.set(xticks=np.arange(0.0005, 0.014, 0.001))
# Out:
# [Text(0.5, 0, 'Background Diversity')]

# %%
filter_qcut.loc[filter_qcut.Origin.isin(gog)]["diversity"].mean(), filter_qcut.loc[filter_qcut.Origin.isin(gog)]["diversity"].median()
# Out:
# (0.001711774744977684, 0.001658228842197082)

# %%
g = lmplot(filter_qcut.loc[filter_qcut.Origin.isin(yellows)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Yellow Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=np.arange(0.0005, 0.004, 0.001))

# %%
g = lmplot(filter_qcut.loc[filter_qcut.Origin.isin(olives)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, 0.11))
g.set(xticks=np.arange(0.0005, 0.004, 0.001))

# %%
g = lmplot(filter_qcut.loc[filter_qcut.Origin.isin(olives_with_tarangire)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=np.arange(0.0005, 0.004, 0.001))

# %%
g = lmplot(filter_qcut.loc[filter_qcut.Origin.isin(gog)], x="diversity", y="minor_parent_percentage",
                            scatter=False, weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Gog Olive Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=np.arange(0.0005, 0.004, 0.001))

# %%
g = lmplot(filter_callable.loc[filter_callable.Origin.isin(["Mahale, Tanzania",
                                                           "Katavi, Tanzania",
                                                           "Issa Valley, Tanzania"])], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Kinda-like Baboons")
g.set(ylim=(-0.01, None))

# %%
g = lmplot(filter_callable.loc[filter_callable.Origin.isin(olives_with_tarangire)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, None))

# %%
o_l, stat_l, pval_l = [], [], []
for o in result_order:
    o_div = filter_qcut.loc[filter_qcut.Origin == o]
    #o_div = o_div.loc[(o_div.minor_parent_percentage < 0.5)]
    st, pval = stats.pearsonr(o_div.diversity, o_div["minor_parent_percentage"])
    print(o, stats.pearsonr(o_div.diversity, o_div["minor_parent_percentage"]))
    o_l.append(o), stat_l.append(st), pval_l.append(pval)
pd.DataFrame({"Origin": o_l, "Statistic": stat_l, "P-Value": pval_l})
# Out:
# Selous, Tanzania PearsonRResult(statistic=-0.008666153305331412, pvalue=0.16719329920409046)
# Udzungwa, Tanzania PearsonRResult(statistic=0.03930895584863133, pvalue=3.664890739648425e-10)
# Katavi, Tanzania PearsonRResult(statistic=0.02490997529990865, pvalue=7.160571725090047e-05)
# Ruaha, Tanzania PearsonRResult(statistic=0.03928743542002018, pvalue=3.7465633749587867e-10)
# Tarangire, Tanzania PearsonRResult(statistic=-0.014241002342076854, pvalue=0.023212816128072317)
# Arusha, Tanzania PearsonRResult(statistic=-0.016368159134661896, pvalue=0.009080464425685166)
# Ngorongoro, Tanzania PearsonRResult(statistic=0.010602308220162065, pvalue=0.09104827673123973)
# Gombe, Tanzania PearsonRResult(statistic=0.044147424782121185, pvalue=1.9243502631780427e-12)
# Lake Manyara, Tanzania PearsonRResult(statistic=0.0004415501277517651, pvalue=0.9438941048269498)
# Serengeti, Tanzania PearsonRResult(statistic=0.010972148531582987, pvalue=0.08031767088113534)
#                    Origin  Statistic    P-Value
# 0        Selous, Tanzania   -0.00867      0.167
# 1      Udzungwa, Tanzania     0.0393   3.66e-10
# 2        Katavi, Tanzania     0.0249   7.16e-05
# 3         Ruaha, Tanzania     0.0393   3.75e-10
# 4     Tarangire, Tanzania    -0.0142     0.0232
# 5        Arusha, Tanzania    -0.0164    0.00908
# 6    Ngorongoro, Tanzania     0.0106      0.091
# 7         Gombe, Tanzania     0.0441   1.92e-12
# 8  Lake Manyara, Tanzania   0.000442      0.944
# 9     Serengeti, Tanzania      0.011     0.0803

# %% [markdown]
# Recomb investigation for autosomes

# %%
filter_callable = admix_div_mean.loc[admix_div_mean.callable_frac > 0.75]
filter_callable.loc[filter_callable['Origin'] == 'Gog Woreda, Gambella region, Ethiopia_eth_case', ['Origin']] = 'Gog Woreda, Ethiopia'
filter_callable["average_cM_window"].quantile([0.005, 0.995])
# Out:
# 0.005     1.13e-07
# 0.995     4.08e-06
# Name: average_cM_window, dtype: float64

# %%
len(filter_callable)
# Out:
# 307920

# %%
len(filter_callable)/len(admix_div_mean)
# Out:
# 0.9890152245133937

# %%
filter_qcut_recomb = filter_callable.loc[(filter_callable.average_cM_window >= 1.13e-07) &
                                 (filter_callable.average_cM_window <=  4.08e-06)]
filter_callable["window_cM"] = filter_callable["average_cM_window"]*100000
filter_qcut_recomb["window_cM"] = filter_qcut_recomb["average_cM_window"]*100000
# Out:
# /tmp/50076219/ipykernel_3073965/436718125.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_callable["window_cM"] = filter_callable["average_cM_window"]*100000
# /tmp/50076219/ipykernel_3073965/436718125.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_recomb["window_cM"] = filter_qcut_recomb["average_cM_window"]*100000

# %%
import statsmodels.api as sm
import numpy as np

df_l = []
for o in result_order:
    o_div = filter_qcut_recomb.loc[filter_qcut_recomb.Origin == o]
    Y = o_div["minor_parent_percentage"]
    X = o_div.window_cM
    X = sm.add_constant(X)
    model = sm.OLS(Y,X)
    results = model.fit()
    print(o)
    #print(results.t_test([1, 0]))
    het_test = sm.stats.het_breuschpagan(resid=results.resid, exog_het=X)
    print(het_test)
    #print(sm.stats.diagnostic.linear_harvey_collier(results))
    df_l.append(list(het_test))
bp_df = pd.DataFrame(df_l, columns=["Lagrange Multiplier", "Lagrange Multiplier P-value", "F-statistic", "F-statistic P-value"])
bp_df["Origin"] = result_order
bp_df
# Out:
# Selous, Tanzania
# (1.6601283651916838, 0.19758599314136685, 1.6601061508139405, 0.19760072869138637)
# Udzungwa, Tanzania
# (1.112555845453475, 0.2915270385598105, 1.112516973975056, 0.2915455010585673)
# Katavi, Tanzania
# (3.1305147963147473, 0.07683947269629512, 3.130654142383844, 0.07684490269995448)
# Ruaha, Tanzania
# (6.565548468429899, 0.01039716894296213, 6.5667288581636, 0.010395986558929326)
# Tarangire, Tanzania
# (1.4644671369795565, 0.22622068786465171, 1.4644362596320835, 0.22623684433655114)
# Arusha, Tanzania
# (0.8777511030367818, 0.348818374792896, 0.8777123215220112, 0.3488379303510728)
# Ngorongoro, Tanzania
# (1.2829239347033219, 0.25735608619664196, 1.2828877156355152, 0.2573734952002354)
# Gombe, Tanzania
# (0.1077610920156431, 0.7427076411880115, 0.10775306435592755, 0.7427195915083464)
# Lake Manyara, Tanzania
# (2.2596182152094566, 0.13278679368797144, 2.2596413123421315, 0.13279724614299765)
# Serengeti, Tanzania
# (24.43606377173115, 7.681717037617767e-07, 24.45766831545352, 7.644506060768679e-07)
#    Lagrange Multiplier  Lagrange Multiplier P-value  F-statistic  \
# 0                 1.66                        0.198         1.66
# 1                 1.11                        0.292         1.11
# 2                 3.13                       0.0768         3.13
# 3                 6.57                       0.0104         6.57
# 4                 1.46                        0.226         1.46
# 5                0.878                        0.349        0.878
# 6                 1.28                        0.257         1.28
# 7                0.108                        0.743        0.108
# 8                 2.26                        0.133         2.26
# 9                 24.4                     7.68e-07         24.5
#
#    F-statistic P-value                  Origin
# 0                0.198        Selous, Tanzania
# 1                0.292      Udzungwa, Tanzania
# 2               0.0768        Katavi, Tanzania
# 3               0.0104         Ruaha, Tanzania
# 4                0.226     Tarangire, Tanzania
# 5                0.349        Arusha, Tanzania
# 6                0.257    Ngorongoro, Tanzania
# 7                0.743         Gombe, Tanzania
# 8                0.133  Lake Manyara, Tanzania
# 9             7.64e-07     Serengeti, Tanzania

# %%
filter_qcut_recomb["Recombination Quantile"] = pd.qcut(filter_qcut_recomb.window_cM, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
g = sns.FacetGrid(filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 4, col_order=result_order_no_gog)
g.map_dataframe(sns.pointplot, y="minor_parent_percentage", x="Recombination Quantile", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Recombination Quantile", ylabel="Minor Parent Ancestry")
# Out:
# /tmp/50076219/ipykernel_3073965/3329632309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_recomb["Recombination Quantile"] = pd.qcut(filter_qcut_recomb.window_cM, 5,

# %%
o_l, low_l, high_l, effect_l, effect_hl_l = [], [], [], [], []
filter_qcut_recomb["Recombination Quantile"] = pd.qcut(filter_qcut_recomb.window_cM, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
for o in result_order:
    s_df = filter_qcut_recomb.loc[filter_qcut_recomb.Origin == o]
    #print(o, s_df.groupby(["Recombination Quantile"])[["minor_parent_percentage"]].mean())
    low_mean = s_df.loc[s_df["Recombination Quantile"] == "0-20"][["minor_parent_percentage"]].mean()[0]*100
    high_mean = s_df.loc[s_df["Recombination Quantile"] == "80-100"][["minor_parent_percentage"]].mean()[0]*100
    o_l.append(o)
    low_l.append(low_mean)
    high_l.append(high_mean)
    effect_l.append(high_mean/low_mean-1)
# Out:
# /tmp/50076219/ipykernel_3073965/3586050451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_recomb["Recombination Quantile"] = pd.qcut(filter_qcut_recomb.window_cM, 5,

# %%
mean_quantile_df = pd.DataFrame({"Origin": o_l, "0-20 Minor Parent Percentage": low_l, 
                        "80-100 Minor Parent Percentage": high_l, "Relative Increase": effect_l})
mean_quantile_df["Absolute Increase"] = mean_quantile_df["80-100 Minor Parent Percentage"]-mean_quantile_df["0-20 Minor Parent Percentage"]
mean_quantile_df
# Out:
#                    Origin  0-20 Minor Parent Percentage  \
# 0        Selous, Tanzania                         0.174
# 1      Udzungwa, Tanzania                         0.861
# 2        Katavi, Tanzania                           6.4
# 3         Ruaha, Tanzania                          7.56
# 4     Tarangire, Tanzania                          23.2
# 5        Arusha, Tanzania                          8.64
# 6    Ngorongoro, Tanzania                           6.8
# 7         Gombe, Tanzania                          8.28
# 8  Lake Manyara, Tanzania                          7.25
# 9     Serengeti, Tanzania                          4.99
#
#    80-100 Minor Parent Percentage  Relative Increase  Absolute Increase
# 0                            0.17            -0.0195           -0.00339
# 1                            1.03              0.192              0.166
# 2                             6.6             0.0315              0.201
# 3                            7.59            0.00345             0.0261
# 4                            21.8            -0.0597              -1.39
# 5                            8.75             0.0136              0.117
# 6                            6.81              0.002             0.0136
# 7                            7.84            -0.0538             -0.445
# 8                             6.7            -0.0757             -0.549
# 9                            4.64            -0.0706             -0.352

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_callable.loc[filter_callable.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ window_cM", data=o_div,
                         var_weights=np.asarray(o_div["window_cM"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.9760e-05
# Method:                               IRLS   Log-Likelihood:                 68147.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.50701
# Time:                             11:10:13   Pearson chi2:                    0.507
# No. Iterations:                          3   Pseudo R-squ. (CS):          5.249e-06
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0016      0.000     11.053      0.000       0.001       0.002
# window_cM     -0.0003      0.001     -0.367      0.714      -0.002       0.001
# ==============================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      9.9239e-05
# Method:                               IRLS   Log-Likelihood:                 47441.
# Date:                     Mon, 20 Jul 2026   Deviance:                       2.5463
# Time:                             11:10:13   Pearson chi2:                     2.55
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0003014
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0111      0.000     34.381      0.000       0.010       0.012
# window_cM     -0.0051      0.002     -2.781      0.005      -0.009      -0.001
# ==============================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012680
# Method:                               IRLS   Log-Likelihood:                 14755.
# Date:                     Mon, 20 Jul 2026   Deviance:                       32.533
# Time:                             11:10:13   Pearson chi2:                     32.5
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0001251
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0641      0.001     55.398      0.000       0.062       0.066
# window_cM      0.0117      0.007      1.792      0.073      -0.001       0.024
# ==============================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00074170
# Method:                               IRLS   Log-Likelihood:                 21635.
# Date:                     Mon, 20 Jul 2026   Deviance:                       19.031
# Time:                             11:10:13   Pearson chi2:                     19.0
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001290
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0724      0.001     81.875      0.000       0.071       0.074
# window_cM      0.0287      0.005      5.756      0.000       0.019       0.038
# ==============================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0025375
# Method:                               IRLS   Log-Likelihood:                 5854.1
# Date:                     Mon, 20 Jul 2026   Deviance:                       65.108
# Time:                             11:10:13   Pearson chi2:                     65.1
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0009263
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2191      0.002    133.884      0.000       0.216       0.222
# window_cM      0.0450      0.009      4.876      0.000       0.027       0.063
# ==============================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0015927
# Method:                               IRLS   Log-Likelihood:                 11830.
# Date:                     Mon, 20 Jul 2026   Deviance:                       40.866
# Time:                             11:10:13   Pearson chi2:                     40.9
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.004077
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0794      0.001     61.211      0.000       0.077       0.082
# window_cM      0.0748      0.007     10.238      0.000       0.061       0.089
# ==============================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012230
# Method:                               IRLS   Log-Likelihood:                 15219.
# Date:                     Mon, 20 Jul 2026   Deviance:                       31.379
# Time:                             11:10:13   Pearson chi2:                     31.4
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.005187
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0600      0.001     52.834      0.000       0.058       0.062
# window_cM      0.0740      0.006     11.552      0.000       0.061       0.087
# ==============================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012828
# Method:                               IRLS   Log-Likelihood:                 14606.
# Date:                     Mon, 20 Jul 2026   Deviance:                       32.915
# Time:                             11:10:13   Pearson chi2:                     32.9
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.002802
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0703      0.001     60.390      0.000       0.068       0.073
# window_cM      0.0557      0.007      8.485      0.000       0.043       0.069
# ==============================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00081586
# Method:                               IRLS   Log-Likelihood:                 20412.
# Date:                     Mon, 20 Jul 2026   Deviance:                       20.933
# Time:                             11:10:13   Pearson chi2:                     20.9
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.003861
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0606      0.001     65.256      0.000       0.059       0.062
# window_cM      0.0521      0.005      9.963      0.000       0.042       0.062
# ==============================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25660
# Model:                                 GLM   Df Residuals:                    25658
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00055758
# Method:                               IRLS   Log-Likelihood:                 25296.
# Date:                     Mon, 20 Jul 2026   Deviance:                       14.306
# Time:                             11:10:13   Pearson chi2:                     14.3
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001084
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0438      0.001     57.113      0.000       0.042       0.045
# window_cM      0.0228      0.004      5.275      0.000       0.014       0.031
# ==============================================================================

# %%
glm_recomb_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_recomb_df
# Out:
#                    Origin  Intercept      Slope  Intercept P-value  \
# 0        Selous, Tanzania     0.0016  -0.000299           2.11e-28
# 1      Udzungwa, Tanzania     0.0111   -0.00507          4.79e-259
# 2        Katavi, Tanzania     0.0641     0.0117                  0
# 3         Ruaha, Tanzania     0.0724     0.0287                  0
# 4     Tarangire, Tanzania      0.219      0.045                  0
# 5        Arusha, Tanzania     0.0794     0.0748                  0
# 6    Ngorongoro, Tanzania       0.06      0.074                  0
# 7         Gombe, Tanzania     0.0703     0.0557                  0
# 8  Lake Manyara, Tanzania     0.0606     0.0521                  0
# 9     Serengeti, Tanzania     0.0438     0.0228                  0
#
#    Slope P-value  Intercept stderr  Slope stderr
# 0          0.714          0.000144      0.000814
# 1        0.00542          0.000324       0.00182
# 2         0.0731           0.00116       0.00652
# 3       8.61e-09          0.000885       0.00499
# 4       1.08e-06           0.00164       0.00923
# 5       1.34e-24            0.0013       0.00731
# 6       7.23e-31           0.00114        0.0064
# 7       2.16e-17           0.00116       0.00656
# 8       2.21e-23          0.000928       0.00523
# 9       1.32e-07          0.000767       0.00432

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut_recomb.loc[filter_qcut_recomb.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ window_cM", data=o_div,
                         var_weights=np.asarray(o_div["window_cM"])
                         ).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# Selous, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      1.9347e-05
# Method:                               IRLS   Log-Likelihood:                 67732.
# Date:                     Mon, 20 Jul 2026   Deviance:                      0.49140
# Time:                             11:10:14   Pearson chi2:                    0.491
# No. Iterations:                          3   Pseudo R-squ. (CS):          8.233e-06
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0016      0.000      9.003      0.000       0.001       0.002
# window_cM     -0.0006      0.001     -0.457      0.648      -0.003       0.002
# ==============================================================================
# Udzungwa, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      9.8794e-05
# Method:                               IRLS   Log-Likelihood:                 47024.
# Date:                     Mon, 20 Jul 2026   Deviance:                       2.5093
# Time:                             11:10:14   Pearson chi2:                     2.51
# No. Iterations:                          3   Pseudo R-squ. (CS):          3.537e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0103      0.000     25.118      0.000       0.009       0.011
# window_cM      0.0028      0.003      0.948      0.343      -0.003       0.009
# ==============================================================================
# Katavi, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012307
# Method:                               IRLS   Log-Likelihood:                 14989.
# Date:                     Mon, 20 Jul 2026   Deviance:                       31.259
# Time:                             11:10:14   Pearson chi2:                     31.3
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0001798
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0680      0.001     47.063      0.000       0.065       0.071
# window_cM     -0.0224      0.010     -2.137      0.033      -0.043      -0.002
# ==============================================================================
# Ruaha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00071499
# Method:                               IRLS   Log-Likelihood:                 21887.
# Date:                     Mon, 20 Jul 2026   Deviance:                       18.160
# Time:                             11:10:14   Pearson chi2:                     18.2
# No. Iterations:                          3   Pseudo R-squ. (CS):          3.422e-06
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0754      0.001     68.538      0.000       0.073       0.078
# window_cM      0.0024      0.008      0.295      0.768      -0.013       0.018
# ==============================================================================
# Tarangire, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0024625
# Method:                               IRLS   Log-Likelihood:                 6180.2
# Date:                     Mon, 20 Jul 2026   Deviance:                       62.546
# Time:                             11:10:14   Pearson chi2:                     62.5
# No. Iterations:                          3   Pseudo R-squ. (CS):          3.067e-05
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2225      0.002    108.911      0.000       0.218       0.226
# window_cM      0.0131      0.015      0.883      0.377      -0.016       0.042
# ==============================================================================
# Arusha, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0015374
# Method:                               IRLS   Log-Likelihood:                 12163.
# Date:                     Mon, 20 Jul 2026   Deviance:                       39.049
# Time:                             11:10:14   Pearson chi2:                     39.0
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001213
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0807      0.002     49.986      0.000       0.078       0.084
# window_cM      0.0650      0.012      5.553      0.000       0.042       0.088
# ==============================================================================
# Ngorongoro, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0011567
# Method:                               IRLS   Log-Likelihood:                 15777.
# Date:                     Mon, 20 Jul 2026   Deviance:                       29.379
# Time:                             11:10:14   Pearson chi2:                     29.4
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.001266
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0620      0.001     44.259      0.000       0.059       0.065
# window_cM      0.0576      0.010      5.673      0.000       0.038       0.077
# ==============================================================================
# Gombe, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                       0.0012391
# Method:                               IRLS   Log-Likelihood:                 14903.
# Date:                     Mon, 20 Jul 2026   Deviance:                       31.471
# Time:                             11:10:14   Pearson chi2:                     31.5
# No. Iterations:                          3   Pseudo R-squ. (CS):          0.0005699
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0720      0.001     49.662      0.000       0.069       0.075
# window_cM      0.0400      0.011      3.805      0.000       0.019       0.061
# ==============================================================================
# Lake Manyara, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00077739
# Method:                               IRLS   Log-Likelihood:                 20824.
# Date:                     Mon, 20 Jul 2026   Deviance:                       19.745
# Time:                             11:10:14   Pearson chi2:                     19.7
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.002524
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0589      0.001     51.323      0.000       0.057       0.061
# window_cM      0.0667      0.008      8.012      0.000       0.050       0.083
# ==============================================================================
# Serengeti, Tanzania                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                25401
# Model:                                 GLM   Df Residuals:                    25399
# Model Family:                     Gaussian   Df Model:                            1
# Link Function:                    Identity   Scale:                      0.00052592
# Method:                               IRLS   Log-Likelihood:                 25787.
# Date:                     Mon, 20 Jul 2026   Deviance:                       13.358
# Time:                             11:10:14   Pearson chi2:                     13.4
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.002336
# Covariance Type:                 nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0405      0.001     42.885      0.000       0.039       0.042
# window_cM      0.0528      0.007      7.707      0.000       0.039       0.066
# ==============================================================================

# %%
glm_recomb_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_recomb_df
# Out:
#                    Origin  Intercept      Slope  Intercept P-value  \
# 0        Selous, Tanzania    0.00163    -0.0006           2.21e-19
# 1      Udzungwa, Tanzania     0.0103    0.00281          3.17e-139
# 2        Katavi, Tanzania      0.068    -0.0224                  0
# 3         Ruaha, Tanzania     0.0754    0.00235                  0
# 4     Tarangire, Tanzania      0.222     0.0131                  0
# 5        Arusha, Tanzania     0.0807      0.065                  0
# 6    Ngorongoro, Tanzania      0.062     0.0576                  0
# 7         Gombe, Tanzania      0.072       0.04                  0
# 8  Lake Manyara, Tanzania     0.0589     0.0667                  0
# 9     Serengeti, Tanzania     0.0405     0.0528                  0
#
#    Slope P-value  Intercept stderr  Slope stderr
# 0          0.648          0.000181       0.00131
# 1          0.343          0.000409       0.00297
# 2         0.0326           0.00144        0.0105
# 3          0.768            0.0011       0.00798
# 4          0.377           0.00204        0.0148
# 5       2.81e-08           0.00161        0.0117
# 6       1.41e-08            0.0014        0.0102
# 7       0.000142           0.00145        0.0105
# 8       1.13e-15           0.00115       0.00832
# 9       1.29e-14          0.000944       0.00685

# %%
filter_callable.loc[filter_callable['Origin'] == 'Gog Woreda, Gambella region, Ethiopia_eth_case', ['Origin']] = 'Gog Woreda, Ethiopia'
filter_callable["average_cM_window"].quantile([0.000, 0.99])
# Out:
#    0     7.12e-09
# 0.99     3.25e-06
# Name: average_cM_window, dtype: float64

# %%
g = sns.histplot(filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(gog)], x="window_cM")
g.set(xlabel="Recombination across window (cM)")
# Out:
# [Text(0.5, 0, 'Recombination across window (cM)')]

# %%
filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(gog)]["window_cM"].mean(), filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(gog)]["window_cM"].median()
# Out:
# (0.08150930258188299, 0.06682910775519701)

# %%
g = sns.histplot(filter_callable.loc[filter_callable.Origin.isin(gog)], x="window_cM")
g.set(xlabel="Recombination across window (cM)")
# Out:
# [Text(0.5, 0, 'Recombination across window (cM)')]

# %%
filter_callable.loc[filter_callable.Origin.isin(gog)]["window_cM"].mean(), filter_callable.loc[filter_callable.Origin.isin(gog)]["window_cM"].median()
# Out:
# (0.0835180564270441, 0.06682918646315805)

# %%
g = lmplot(filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(yellows)], x="window_cM", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5)
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Recombination across window (cM)", title="Tanzanian Yellow Baboons")
g.set(ylim=(-0.01, None))

# %%
g = lmplot(filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(olives)], x="window_cM", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=95)
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Recombination across window (cM)", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, 0.11))

# %%
g = lmplot(filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(olives_with_tarangire)], x="window_cM", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=95)
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Recombination across window (cM)", title="Tanzanian Olive Baboons")
#g.set(ylim=(-0.01, 0.11))

# %%
g = lmplot(filter_callable.loc[filter_callable.Origin.isin(yellows)], x="window_cM", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5)
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Recombination across window (cM)", title="Tanzanian Yellow Baboons")
g.set(ylim=(-0.01, None))

# %%
g = lmplot(filter_callable.loc[filter_callable.Origin.isin(olives_with_tarangire)], x="window_cM", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5)
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Recombination across window (cM)", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, None))

# %%
g = lmplot(filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(gog)], x="window_cM", y="minor_parent_percentage",
                            scatter=False, weighted=True, n_boot=1000, ci=99.5)
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Recombination across window (cM)", title="Gog Olive Baboon")
g.set(ylim=(-0.01, None))

# %%
norm_filter = filter_qcut_recomb.loc[(filter_qcut_recomb.diversity >= 0.000513) &
                                 (filter_qcut_recomb.diversity <= 0.00408)]
g = sns.regplot(norm_filter.loc[(norm_filter.Origin == "Serengeti, Tanzania") &
                              #(admix_div_mean["minor_parent_percentage"] < 0.5) &
                              (norm_filter.callable_frac > 0.75)], x="window_cM", y="diversity",
                            ci=95, scatter_kws={'alpha':0.3})
g.set(xlabel="Recombination across window (cM)", ylabel = "Background Diversity")
# Out:
# [Text(0.5, 0, 'Recombination across window (cM)'),
#  Text(0, 0.5, 'Background Diversity')]

# %%
stats.pearsonr(norm_filter.window_cM, norm_filter.diversity)
# Out:
# PearsonRResult(statistic=0.5730825286503438, pvalue=0.0)

# %%
norm_filter["norm_diversity"] = (norm_filter.diversity-norm_filter.diversity.mean())/(norm_filter.diversity.std())
norm_filter["norm_recomb"] = (norm_filter.window_cM-norm_filter.window_cM.mean())/(norm_filter.window_cM.std())
# Out:
# /tmp/50076219/ipykernel_3073965/1414838712.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norm_filter["norm_diversity"] = (norm_filter.diversity-norm_filter.diversity.mean())/(norm_filter.diversity.std())
# /tmp/50076219/ipykernel_3073965/1414838712.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norm_filter["norm_recomb"] = (norm_filter.window_cM-norm_filter.window_cM.mean())/(norm_filter.window_cM.std())

# %%
o_l, cd_l, cr_l, nd_l, rd_l = [], [], [], [], []
for o in result_order:
    o_div = norm_filter.loc[norm_filter.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity", data=o_div
                         ).fit()
    print(o, glm_results.summary2(), glm_results.pvalues, glm_results.f_test(np.identity(len(glm_results.params))[1:,:]))
    #o_l.append(o), cd_l.append(glm_results.params[1]), cr_l.append(glm_results.params[2])
    #nd_l.append(glm_results.pvalues[1]), rd_l.append(glm_results.pvalues[2])
# Out:
# Selous, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -137049.1761
# Link Function:      Identity                BIC:            -255420.8858
# Dependent Variable: minor_parent_percentage Log-Likelihood: 68527.
# Date:               2026-07-20 11:16        LL-Null:        68526.
# No. Observations:   25205                   Deviance:       6.4198
# Df Model:           1                       Pearson chi2:   6.42
# Df Residuals:       25203                   Scale:          0.00025472
# Method:             IRLS
# --------------------------------------------------------------------------
#                    Coef.    Std.Err.      z      P>|z|     [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept          0.0016     0.0001   15.9413   0.0000    0.0014   0.0018
# norm_diversity    -0.0001     0.0001   -1.3763   0.1687   -0.0003   0.0001
# ========================================================================
#  Intercept          3.27e-57
# norm_diversity        0.169
# dtype: float64 <F test: F=1.8942675699794693, p=0.16873359411003672, df_denom=2.52e+04, df_num=1>
# Udzungwa, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -97058.1536
# Link Function:      Identity                BIC:            -255395.9306
# Dependent Variable: minor_parent_percentage Log-Likelihood: 48531.
# Date:               2026-07-20 11:16        LL-Null:        48511.
# No. Observations:   25205                   Deviance:       31.375
# Df Model:           1                       Pearson chi2:   31.4
# Df Residuals:       25203                   Scale:          0.0012449
# Method:             IRLS
# --------------------------------------------------------------------------
#                     Coef.    Std.Err.      z      P>|z|    [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept           0.0105     0.0002   47.0652   0.0000   0.0100   0.0109
# norm_diversity      0.0014     0.0002    6.3083   0.0000   0.0010   0.0018
# ========================================================================
#  Intercept                 0
# norm_diversity     2.82e-10
# dtype: float64 <F test: F=39.79432263481146, p=2.8685052771885686e-10, df_denom=2.52e+04, df_num=1>
# Katavi, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -33690.6474
# Link Function:      Identity                BIC:            -255039.6580
# Dependent Variable: minor_parent_percentage Log-Likelihood: 16847.
# Date:               2026-07-20 11:16        LL-Null:        16840.
# No. Observations:   25205                   Deviance:       387.65
# Df Model:           1                       Pearson chi2:   388.
# Df Residuals:       25203                   Scale:          0.015381
# Method:             IRLS
# --------------------------------------------------------------------------
#                     Coef.    Std.Err.      z      P>|z|    [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept           0.0660     0.0008   84.5378   0.0000   0.0645   0.0676
# norm_diversity      0.0030     0.0008    3.8359   0.0001   0.0015   0.0045
# ========================================================================
#  Intercept                 0
# norm_diversity     0.000125
# dtype: float64 <F test: F=14.714403507016904, p=0.00012539170753105824, df_denom=2.52e+04, df_num=1>
# Ruaha, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -47230.1136
# Link Function:      Identity                BIC:            -255200.7653
# Dependent Variable: minor_parent_percentage Log-Likelihood: 23617.
# Date:               2026-07-20 11:16        LL-Null:        23598.
# No. Observations:   25205                   Deviance:       226.54
# Df Model:           1                       Pearson chi2:   227.
# Df Residuals:       25203                   Scale:          0.0089886
# Method:             IRLS
# --------------------------------------------------------------------------
#                    Coef.    Std.Err.      z       P>|z|    [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept          0.0760     0.0006   127.2296   0.0000   0.0748   0.0771
# norm_diversity     0.0037     0.0006     6.1178   0.0000   0.0025   0.0048
# ========================================================================
#  Intercept                 0
# norm_diversity     9.49e-10
# dtype: float64 <F test: F=37.42735093150983, p=9.627907500630694e-10, df_denom=2.52e+04, df_num=1>
# Tarangire, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -16849.7806
# Link Function:      Identity                BIC:            -254671.1460
# Dependent Variable: minor_parent_percentage Log-Likelihood: 8426.9
# Date:               2026-07-20 11:16        LL-Null:        8424.4
# No. Observations:   25205                   Deviance:       756.16
# Df Model:           1                       Pearson chi2:   756.
# Df Residuals:       25203                   Scale:          0.030003
# Method:             IRLS
# -------------------------------------------------------------------------
#                      Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# -------------------------------------------------------------------------
# Intercept            0.2254    0.0011  206.6315  0.0000   0.2233   0.2276
# norm_diversity      -0.0024    0.0011   -2.2391  0.0252  -0.0046  -0.0003
# ========================================================================
#  Intercept                 0
# norm_diversity       0.0252
# dtype: float64 <F test: F=5.013396839073544, p=0.02516059789007928, df_denom=2.52e+04, df_num=1>
# Arusha, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -28360.8219
# Link Function:      Identity                BIC:            -254948.3750
# Dependent Variable: minor_parent_percentage Log-Likelihood: 14182.
# Date:               2026-07-20 11:16        LL-Null:        14180.
# No. Observations:   25205                   Deviance:       478.93
# Df Model:           1                       Pearson chi2:   479.
# Df Residuals:       25203                   Scale:          0.019003
# Method:             IRLS
# -------------------------------------------------------------------------
#                      Coef.   Std.Err.     z      P>|z|    [0.025   0.975]
# -------------------------------------------------------------------------
# Intercept            0.0874    0.0009  100.6342  0.0000   0.0857   0.0891
# norm_diversity      -0.0019    0.0009   -2.2337  0.0255  -0.0036  -0.0002
# ========================================================================
#  Intercept                 0
# norm_diversity       0.0255
# dtype: float64 <F test: F=4.9892463934024205, p=0.02551405277651127, df_denom=2.52e+04, df_num=1>
# Ngorongoro, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -36180.9758
# Link Function:      Identity                BIC:            -255076.1274
# Dependent Variable: minor_parent_percentage Log-Likelihood: 18092.
# Date:               2026-07-20 11:16        LL-Null:        18091.
# No. Observations:   25205                   Deviance:       351.18
# Df Model:           1                       Pearson chi2:   351.
# Df Residuals:       25203                   Scale:          0.013934
# Method:             IRLS
# --------------------------------------------------------------------------
#                    Coef.    Std.Err.      z      P>|z|     [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept          0.0677     0.0007   91.1153   0.0000    0.0663   0.0692
# norm_diversity     0.0013     0.0007    1.7712   0.0765   -0.0001   0.0028
# ========================================================================
#  Intercept                 0
# norm_diversity       0.0765
# dtype: float64 <F test: F=3.1372267937867275, p=0.07653590230695806, df_denom=2.52e+04, df_num=1>
# Gombe, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -34080.3838
# Link Function:      Identity                BIC:            -255045.6060
# Dependent Variable: minor_parent_percentage Log-Likelihood: 17042.
# Date:               2026-07-20 11:16        LL-Null:        17018.
# No. Observations:   25205                   Deviance:       381.70
# Df Model:           1                       Pearson chi2:   382.
# Df Residuals:       25203                   Scale:          0.015145
# Method:             IRLS
# --------------------------------------------------------------------------
#                     Coef.    Std.Err.      z      P>|z|    [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept           0.0762     0.0008   98.2779   0.0000   0.0747   0.0777
# norm_diversity      0.0054     0.0008    6.9987   0.0000   0.0039   0.0069
# ========================================================================
#  Intercept                 0
# norm_diversity     2.58e-12
# dtype: float64 <F test: F=48.98175673136781, p=2.64823152178697e-12, df_denom=2.52e+04, df_num=1>
# Lake Manyara, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -46390.6020
# Link Function:      Identity                BIC:            -255193.0928
# Dependent Variable: minor_parent_percentage Log-Likelihood: 23197.
# Date:               2026-07-20 11:16        LL-Null:        23197.
# No. Observations:   25205                   Deviance:       234.21
# Df Model:           1                       Pearson chi2:   234.
# Df Residuals:       25203                   Scale:          0.0092931
# Method:             IRLS
# --------------------------------------------------------------------------
#                   Coef.    Std.Err.      z       P>|z|     [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept         0.0662     0.0006   109.0905   0.0000    0.0651   0.0674
# norm_diversity    0.0002     0.0006     0.2842   0.7763   -0.0010   0.0014
# ========================================================================
#  Intercept                 0
# norm_diversity        0.776
# dtype: float64 <F test: F=0.08077103823374804, p=0.7762575652017846, df_denom=2.52e+04, df_num=1>
# Serengeti, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -57879.9124
# Link Function:      Identity                BIC:            -255278.8337
# Dependent Variable: minor_parent_percentage Log-Likelihood: 28942.
# Date:               2026-07-20 11:16        LL-Null:        28940.
# No. Observations:   25205                   Deviance:       148.47
# Df Model:           1                       Pearson chi2:   148.
# Df Residuals:       25203                   Scale:          0.0058910
# Method:             IRLS
# --------------------------------------------------------------------------
#                     Coef.    Std.Err.      z      P>|z|    [0.025   0.975]
# --------------------------------------------------------------------------
# Intercept           0.0460     0.0005   95.2504   0.0000   0.0451   0.0470
# norm_diversity      0.0010     0.0005    1.9961   0.0459   0.0000   0.0019
# ========================================================================
#  Intercept                 0
# norm_diversity       0.0459
# dtype: float64 <F test: F=3.9842995422064442, p=0.04593693303470409, df_denom=2.52e+04, df_num=1>

# %%
o_l, cd_l, cr_l, nd_l, rd_l = [], [], [], [], []
for o in result_order:
    o_div = norm_filter.loc[norm_filter.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity + window_cM", data=o_div
                         ).fit()
    print(o, glm_results.summary2(), glm_results.pvalues, glm_results.f_test(np.identity(len(glm_results.params))[1:,:]))
    o_l.append(o), cd_l.append(glm_results.params[1]), cr_l.append(glm_results.params[2])
    nd_l.append(glm_results.pvalues[1]), rd_l.append(glm_results.pvalues[2])
# Out:
# Selous, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -137047.4376
# Link Function:      Identity                BIC:            -255410.7511
# Dependent Variable: minor_parent_percentage Log-Likelihood: 68527.
# Date:               2026-07-20 11:16        LL-Null:        68526.
# No. Observations:   25205                   Deviance:       6.4197
# Df Model:           2                       Pearson chi2:   6.42
# Df Residuals:       25202                   Scale:          0.00025473
# Method:             IRLS
# ---------------------------------------------------------------------------
#                Coef.     Std.Err.       z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------------
# Intercept      0.0020      0.0003     6.4353    0.0000     0.0014    0.0026
# diversity     -0.3009      0.2117    -1.4209    0.1553    -0.7159    0.1141
# window_cM      0.0012      0.0023     0.5113    0.6091    -0.0034    0.0058
# ========================================================================
#  Intercept     1.23e-10
# diversity        0.155
# window_cM        0.609
# dtype: float64 <F test: F=1.0778204602653112, p=0.34035218220214564, df_denom=2.52e+04, df_num=2>
# Udzungwa, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -97064.9202
# Link Function:      Identity                BIC:            -255385.8067
# Dependent Variable: minor_parent_percentage Log-Likelihood: 48535.
# Date:               2026-07-20 11:16        LL-Null:        48511.
# No. Observations:   25205                   Deviance:       31.364
# Df Model:           2                       Pearson chi2:   31.4
# Df Residuals:       25202                   Scale:          0.0012445
# Method:             IRLS
# ---------------------------------------------------------------------------
#               Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept     0.0062      0.0007     8.9431    0.0000     0.0048     0.0076
# diversity     3.2140      0.4680     6.8673    0.0000     2.2967     4.1313
# window_cM    -0.0153      0.0052    -2.9609    0.0031    -0.0255    -0.0052
# ========================================================================
#  Intercept     3.78e-19
# diversity     6.54e-12
# window_cM      0.00307
# dtype: float64 <F test: F=24.286806817259514, p=2.900850657336159e-11, df_denom=2.52e+04, df_num=2>
# Katavi, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -33704.6966
# Link Function:      Identity                BIC:            -255029.7700
# Dependent Variable: minor_parent_percentage Log-Likelihood: 16855.
# Date:               2026-07-20 11:16        LL-Null:        16840.
# No. Observations:   25205                   Deviance:       387.40
# Df Model:           2                       Pearson chi2:   387.
# Df Residuals:       25202                   Scale:          0.015372
# Method:             IRLS
# ---------------------------------------------------------------------------
#               Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept     0.0566      0.0024    23.2290    0.0000     0.0519     0.0614
# diversity     8.9489      1.6448     5.4406    0.0000     5.7251    12.1727
# window_cM    -0.0729      0.0182    -4.0066    0.0001    -0.1085    -0.0372
# ========================================================================
#  Intercept    2.32e-119
# diversity     5.31e-08
# window_cM     6.16e-05
# dtype: float64 <F test: F=15.38783028040758, p=2.095208824192511e-07, df_denom=2.52e+04, df_num=2>
# Ruaha, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -47255.2040
# Link Function:      Identity                BIC:            -255190.8739
# Dependent Variable: minor_parent_percentage Log-Likelihood: 23631.
# Date:               2026-07-20 11:16        LL-Null:        23598.
# No. Observations:   25205                   Deviance:       226.30
# Df Model:           2                       Pearson chi2:   226.
# Df Residuals:       25202                   Scale:          0.0089793
# Method:             IRLS
# ---------------------------------------------------------------------------
#               Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept     0.0646      0.0019    34.6873    0.0000     0.0610     0.0683
# diversity    10.0566      1.2571     7.9995    0.0000     7.5926    12.5205
# window_cM    -0.0724      0.0139    -5.2059    0.0000    -0.0996    -0.0451
# ========================================================================
#  Intercept    1.22e-263
# diversity     1.25e-15
# window_cM     1.93e-07
# dtype: float64 <F test: F=32.283925413000794, p=9.935720540898358e-15, df_denom=2.52e+04, df_num=2>
# Tarangire, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -16850.0837
# Link Function:      Identity                BIC:            -254661.0803
# Dependent Variable: minor_parent_percentage Log-Likelihood: 8428.0
# Date:               2026-07-20 11:16        LL-Null:        8424.4
# No. Observations:   25205                   Deviance:       756.09
# Df Model:           2                       Pearson chi2:   756.
# Df Residuals:       25202                   Scale:          0.030001
# Method:             IRLS
# ---------------------------------------------------------------------------
#                Coef.     Std.Err.       z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------------
# Intercept      0.2324      0.0034    68.2086    0.0000     0.2257    0.2390
# diversity     -2.2181      2.2979    -0.9653    0.3344    -6.7220    2.2857
# window_cM     -0.0386      0.0254    -1.5175    0.1291    -0.0884    0.0112
# ========================================================================
#  Intercept            0
# diversity        0.334
# window_cM        0.129
# dtype: float64 <F test: F=3.658257482212262, p=0.0257910805556943, df_denom=2.52e+04, df_num=2>
# Arusha, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -28363.5965
# Link Function:      Identity                BIC:            -254938.3309
# Dependent Variable: minor_parent_percentage Log-Likelihood: 14185.
# Date:               2026-07-20 11:16        LL-Null:        14180.
# No. Observations:   25205                   Deviance:       478.84
# Df Model:           2                       Pearson chi2:   479.
# Df Residuals:       25202                   Scale:          0.019000
# Method:             IRLS
# ---------------------------------------------------------------------------
#               Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept     0.0934      0.0027    34.4653    0.0000     0.0881     0.0988
# diversity    -5.6376      1.8287    -3.0828    0.0021    -9.2217    -2.0534
# window_cM     0.0442      0.0202     2.1851    0.0289     0.0046     0.0838
# ========================================================================
#  Intercept    2.66e-260
# diversity      0.00205
# window_cM       0.0289
# dtype: float64 <F test: F=4.882266972898889, p=0.00758698197713701, df_denom=2.52e+04, df_num=2>
# Ngorongoro, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -36178.9779
# Link Function:      Identity                BIC:            -255065.9926
# Dependent Variable: minor_parent_percentage Log-Likelihood: 18092.
# Date:               2026-07-20 11:16        LL-Null:        18091.
# No. Observations:   25205                   Deviance:       351.18
# Df Model:           2                       Pearson chi2:   351.
# Df Residuals:       25202                   Scale:          0.013935
# Method:             IRLS
# ---------------------------------------------------------------------------
#                Coef.     Std.Err.       z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------------
# Intercept      0.0639      0.0023    27.5068    0.0000     0.0593    0.0684
# diversity      2.2323      1.5661     1.4254    0.1540    -0.8371    5.3018
# window_cM      0.0008      0.0173     0.0454    0.9638    -0.0332    0.0347
# ========================================================================
#  Intercept    1.46e-166
# diversity        0.154
# window_cM        0.964
# dtype: float64 <F test: F=1.5695840443620281, p=0.20815208292000867, df_denom=2.52e+04, df_num=2>
# Gombe, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -34110.1384
# Link Function:      Identity                BIC:            -255035.9517
# Dependent Variable: minor_parent_percentage Log-Likelihood: 17058.
# Date:               2026-07-20 11:16        LL-Null:        17018.
# No. Observations:   25205                   Deviance:       381.22
# Df Model:           2                       Pearson chi2:   381.
# Df Residuals:       25202                   Scale:          0.015127
# Method:             IRLS
# ---------------------------------------------------------------------------
#               Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept     0.0594      0.0024    24.5554    0.0000     0.0547     0.0641
# diversity    14.6347      1.6317     8.9691    0.0000    11.4367    17.8327
# window_cM    -0.1017      0.0180    -5.6366    0.0000    -0.1371    -0.0663
# ========================================================================
#  Intercept    3.78e-133
# diversity     2.99e-19
# window_cM     1.73e-08
# dtype: float64 <F test: F=40.406199981678526, p=3.0191536069780587e-18, df_denom=2.52e+04, df_num=2>
# Lake Manyara, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -46388.8565
# Link Function:      Identity                BIC:            -255182.9603
# Dependent Variable: minor_parent_percentage Log-Likelihood: 23197.
# Date:               2026-07-20 11:16        LL-Null:        23197.
# No. Observations:   25205                   Deviance:       234.21
# Df Model:           2                       Pearson chi2:   234.
# Df Residuals:       25202                   Scale:          0.0092933
# Method:             IRLS
# ---------------------------------------------------------------------------
#                Coef.     Std.Err.       z       P>|z|      [0.025    0.975]
# ---------------------------------------------------------------------------
# Intercept      0.0657      0.0019    34.6390    0.0000     0.0620    0.0694
# diversity      0.6676      1.2789     0.5220    0.6017    -1.8390    3.1743
# window_cM     -0.0071      0.0141    -0.5045    0.6139    -0.0349    0.0206
# ========================================================================
#  Intercept    6.55e-263
# diversity        0.602
# window_cM        0.614
# dtype: float64 <F test: F=0.1676401586131384, p=0.845659025719729, df_denom=2.52e+04, df_num=2>
# Serengeti, Tanzania                    Results: Generalized linear model
# ========================================================================
# Model:              GLM                     AIC:            -57884.9595
# Link Function:      Identity                BIC:            -255268.7404
# Dependent Variable: minor_parent_percentage Log-Likelihood: 28945.
# Date:               2026-07-20 11:16        LL-Null:        28940.
# No. Observations:   25205                   Deviance:       148.43
# Df Model:           2                       Pearson chi2:   148.
# Df Residuals:       25202                   Scale:          0.0058896
# Method:             IRLS
# ---------------------------------------------------------------------------
#               Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------------
# Intercept     0.0430      0.0015    28.4716    0.0000     0.0400     0.0459
# diversity     3.2146      1.0181     3.1573    0.0016     1.2191     5.2101
# window_cM    -0.0299      0.0113    -2.6547    0.0079    -0.0520    -0.0078
# ========================================================================
#  Intercept    2.63e-178
# diversity      0.00159
# window_cM      0.00794
# dtype: float64 <F test: F=5.516223552371258, p=0.004025860865030647, df_denom=2.52e+04, df_num=2>

# %%
pd.DataFrame({"Origin": o_l, "Recombination Slope": cr_l, "Diversity Slope": cd_l,
              "Recombination p-val": rd_l, "Diversity p-val": nd_l})
# Out:
#                    Origin  Recombination Slope  Diversity Slope  \
# 0        Selous, Tanzania               0.0012           -0.301
# 1      Udzungwa, Tanzania              -0.0153             3.21
# 2        Katavi, Tanzania              -0.0729             8.95
# 3         Ruaha, Tanzania              -0.0724             10.1
# 4     Tarangire, Tanzania              -0.0386            -2.22
# 5        Arusha, Tanzania               0.0442            -5.64
# 6    Ngorongoro, Tanzania             0.000787             2.23
# 7         Gombe, Tanzania               -0.102             14.6
# 8  Lake Manyara, Tanzania             -0.00714            0.668
# 9     Serengeti, Tanzania              -0.0299             3.21
#
#    Recombination p-val  Diversity p-val
# 0                0.609            0.155
# 1              0.00307         6.54e-12
# 2             6.16e-05         5.31e-08
# 3             1.93e-07         1.25e-15
# 4                0.129            0.334
# 5               0.0289          0.00205
# 6                0.964            0.154
# 7             1.73e-08         2.99e-19
# 8                0.614            0.602
# 9              0.00794          0.00159

# %%
o_l, cd_l, cr_l, nd_l, rd_l, i_l, id_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = norm_filter.loc[norm_filter.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity * norm_recomb", data=o_div
                         ).fit()
    print(o, glm_results.summary2(), glm_results.pvalues, glm_results.f_test(np.identity(len(glm_results.params))[1:,:]))
    o_l.append(o), cd_l.append(glm_results.params[1]), cr_l.append(glm_results.params[2])
    nd_l.append(glm_results.pvalues[1]), rd_l.append(glm_results.pvalues[2])
    i_l.append(glm_results.params[3]), id_l.append(glm_results.pvalues[3])
# Out:
# Selous, Tanzania                     Results: Generalized linear model
# =========================================================================
# Model:               GLM                     AIC:            -137045.6247
# Link Function:       Identity                BIC:            -255400.6163
# Dependent Variable:  minor_parent_percentage Log-Likelihood: 68527.
# Date:                2026-07-20 11:16        LL-Null:        68526.
# No. Observations:    25205                   Deviance:       6.4196
# Df Model:            3                       Pearson chi2:   6.42
# Df Residuals:        25201                   Scale:          0.00025474
# Method:              IRLS
# -------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                   0.0016   0.0001 14.2254 0.0000  0.0014 0.0018
# norm_diversity             -0.0002   0.0001 -1.3907 0.1643 -0.0004 0.0001
# norm_recomb                 0.0000   0.0001  0.2250 0.8220 -0.0002 0.0003
# norm_diversity:norm_recomb  0.0000   0.0001  0.4325 0.6654 -0.0001 0.0002
# =========================================================================
#  Intercept                      6.37e-46
# norm_diversity                    0.164
# norm_recomb                       0.822
# norm_diversity:norm_recomb        0.665
# dtype: float64 <F test: F=0.7808840916233991, p=0.5044109529547438, df_denom=2.52e+04, df_num=3>
# Udzungwa, Tanzania                     Results: Generalized linear model
# ==========================================================================
# Model:                GLM                     AIC:            -97063.0360
# Link Function:        Identity                BIC:            -255375.6720
# Dependent Variable:   minor_parent_percentage Log-Likelihood: 48536.
# Date:                 2026-07-20 11:16        LL-Null:        48511.
# No. Observations:     25205                   Deviance:       31.364
# Df Model:             3                       Pearson chi2:   31.4
# Df Residuals:         25201                   Scale:          0.0012446
# Method:               IRLS
# --------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                   0.0105   0.0002 42.6977 0.0000  0.0100  0.0110
# norm_diversity              0.0019   0.0003  6.8319 0.0000  0.0013  0.0024
# norm_recomb                -0.0007   0.0003 -2.3896 0.0169 -0.0014 -0.0001
# norm_diversity:norm_recomb -0.0001   0.0002 -0.3403 0.7336 -0.0004  0.0003
# ==========================================================================
#  Intercept                             0
# norm_diversity                 8.38e-12
# norm_recomb                      0.0169
# norm_diversity:norm_recomb        0.734
# dtype: float64 <F test: F=16.22923598014591, p=1.5548956440113152e-10, df_denom=2.52e+04, df_num=3>
# Katavi, Tanzania                     Results: Generalized linear model
# ==========================================================================
# Model:                GLM                     AIC:            -33702.7532
# Link Function:        Identity                BIC:            -255019.6360
# Dependent Variable:   minor_parent_percentage Log-Likelihood: 16855.
# Date:                 2026-07-20 11:16        LL-Null:        16840.
# No. Observations:     25205                   Deviance:       387.40
# Df Model:             3                       Pearson chi2:   387.
# Df Residuals:         25201                   Scale:          0.015372
# Method:               IRLS
# --------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                   0.0661   0.0009 76.5442 0.0000  0.0644  0.0678
# norm_diversity              0.0052   0.0010  5.4146 0.0000  0.0033  0.0070
# norm_recomb                -0.0037   0.0011 -3.3454 0.0008 -0.0058 -0.0015
# norm_diversity:norm_recomb -0.0002   0.0006 -0.2377 0.8121 -0.0014  0.0011
# ==========================================================================
#  Intercept                             0
# norm_diversity                 6.14e-08
# norm_recomb                    0.000822
# norm_diversity:norm_recomb        0.812
# dtype: float64 <F test: F=10.277009363645748, p=9.308013404891365e-07, df_denom=2.52e+04, df_num=3>
# Ruaha, Tanzania                      Results: Generalized linear model
# ===========================================================================
# Model:               GLM                      AIC:             -47260.4856
# Link Function:       Identity                 BIC:             -255180.8044
# Dependent Variable:  minor_parent_percentage  Log-Likelihood:  23634.
# Date:                2026-07-20 11:16         LL-Null:         23598.
# No. Observations:    25205                    Deviance:        226.23
# Df Model:            3                        Pearson chi2:    226.
# Df Residuals:        25201                    Scale:           0.0089771
# Method:              IRLS
# ---------------------------------------------------------------------------
#                             Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------------------
# Intercept                   0.0752   0.0007 113.9343 0.0000  0.0739  0.0765
# norm_diversity              0.0060   0.0007   8.1551 0.0000  0.0045  0.0074
# norm_recomb                -0.0049   0.0008  -5.8576 0.0000 -0.0066 -0.0033
# norm_diversity:norm_recomb  0.0013   0.0005   2.6984 0.0070  0.0004  0.0023
# ===========================================================================
#  Intercept                             0
# norm_diversity                 3.49e-16
# norm_recomb                     4.7e-09
# norm_diversity:norm_recomb      0.00697
# dtype: float64 <F test: F=23.95516068358194, p=1.7878606629561735e-15, df_denom=2.52e+04, df_num=3>
# Tarangire, Tanzania                      Results: Generalized linear model
# ===========================================================================
# Model:               GLM                      AIC:             -16873.9684
# Link Function:       Identity                 BIC:             -254651.7216
# Dependent Variable:  minor_parent_percentage  Log-Likelihood:  8441.0
# Date:                2026-07-20 11:16         LL-Null:         8424.4
# No. Observations:    25205                    Deviance:        755.31
# Df Model:            3                        Pearson chi2:    755.
# Df Residuals:        25201                    Scale:           0.029972
# Method:              IRLS
# ---------------------------------------------------------------------------
#                             Coef.  Std.Err.    z     P>|z|   [0.025  0.975]
# ---------------------------------------------------------------------------
# Intercept                   0.2228   0.0012 184.7140 0.0000  0.2205  0.2252
# norm_diversity             -0.0009   0.0013  -0.6422 0.5208 -0.0035  0.0018
# norm_recomb                -0.0060   0.0015  -3.8682 0.0001 -0.0090 -0.0029
# norm_diversity:norm_recomb  0.0046   0.0009   5.0886 0.0000  0.0028  0.0063
# ===========================================================================
#  Intercept                             0
# norm_diversity                    0.521
# norm_recomb                     0.00011
# norm_diversity:norm_recomb     3.61e-07
# dtype: float64 <F test: F=11.07256990477668, p=2.9274921109181384e-07, df_denom=2.52e+04, df_num=3>
# Arusha, Tanzania                     Results: Generalized linear model
# ==========================================================================
# Model:                GLM                     AIC:            -28367.5233
# Link Function:        Identity                BIC:            -254928.3087
# Dependent Variable:   minor_parent_percentage Log-Likelihood: 14188.
# Date:                 2026-07-20 11:16        LL-Null:        14180.
# No. Observations:     25205                   Deviance:       478.73
# Df Model:             3                       Pearson chi2:   479.
# Df Residuals:         25201                   Scale:          0.018996
# Method:               IRLS
# --------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                   0.0864   0.0010 89.9471 0.0000  0.0845  0.0883
# norm_diversity             -0.0031   0.0011 -2.9231 0.0035 -0.0052 -0.0010
# norm_recomb                 0.0008   0.0012  0.6674 0.5045 -0.0016  0.0032
# norm_diversity:norm_recomb  0.0017   0.0007  2.4344 0.0149  0.0003  0.0031
# ==========================================================================
#  Intercept                             0
# norm_diversity                  0.00347
# norm_recomb                       0.505
# norm_diversity:norm_recomb       0.0149
# dtype: float64 <F test: F=5.230990043148401, p=0.0013135834871721922, df_denom=2.52e+04, df_num=3>
# Ngorongoro, Tanzania                     Results: Generalized linear model
# =========================================================================
# Model:               GLM                     AIC:            -36188.5431
# Link Function:       Identity                BIC:            -255056.0189
# Dependent Variable:  minor_parent_percentage Log-Likelihood: 18098.
# Date:                2026-07-20 11:16        LL-Null:        18091.
# No. Observations:    25205                   Deviance:       351.02
# Df Model:            3                       Pearson chi2:   351.
# Df Residuals:        25201                   Scale:          0.013929
# Method:              IRLS
# -------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                   0.0666   0.0008 80.9288 0.0000  0.0649 0.0682
# norm_diversity              0.0015   0.0009  1.6379 0.1014 -0.0003 0.0033
# norm_recomb                -0.0018   0.0010 -1.6684 0.0952 -0.0038 0.0003
# norm_diversity:norm_recomb  0.0021   0.0006  3.4009 0.0007  0.0009 0.0033
# =========================================================================
#  Intercept                             0
# norm_diversity                    0.101
# norm_recomb                      0.0952
# norm_diversity:norm_recomb     0.000672
# dtype: float64 <F test: F=4.902152587138177, p=0.0020894070875958075, df_denom=2.52e+04, df_num=3>
# Gombe, Tanzania                     Results: Generalized linear model
# ==========================================================================
# Model:                GLM                     AIC:            -34121.3045
# Link Function:        Identity                BIC:            -255026.0160
# Dependent Variable:   minor_parent_percentage Log-Likelihood: 17065.
# Date:                 2026-07-20 11:16        LL-Null:        17018.
# No. Observations:     25205                   Deviance:       381.02
# Df Model:             3                       Pearson chi2:   381.
# Df Residuals:         25201                   Scale:          0.015119
# Method:               IRLS
# --------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                   0.0749   0.0009 87.3663 0.0000  0.0732  0.0765
# norm_diversity              0.0087   0.0009  9.1827 0.0000  0.0068  0.0106
# norm_recomb                -0.0073   0.0011 -6.6977 0.0000 -0.0095 -0.0052
# norm_diversity:norm_recomb  0.0023   0.0006  3.6287 0.0003  0.0011  0.0036
# ==========================================================================
#  Intercept                             0
# norm_diversity                  4.2e-20
# norm_recomb                    2.12e-11
# norm_diversity:norm_recomb     0.000285
# dtype: float64 <F test: F=31.339635038130336, p=3.2684549965914675e-20, df_denom=2.52e+04, df_num=3>
# Lake Manyara, Tanzania                     Results: Generalized linear model
# ==========================================================================
# Model:                GLM                     AIC:            -46425.8323
# Link Function:        Identity                BIC:            -255173.1874
# Dependent Variable:   minor_parent_percentage Log-Likelihood: 23217.
# Date:                 2026-07-20 11:16        LL-Null:        23197.
# No. Observations:     25205                   Deviance:       233.85
# Df Model:             3                       Pearson chi2:   234.
# Df Residuals:         25201                   Scale:          0.0092793
# Method:               IRLS
# --------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                   0.0644   0.0007 96.0194 0.0000  0.0631  0.0658
# norm_diversity              0.0007   0.0007  0.9161 0.3596 -0.0008  0.0021
# norm_recomb                -0.0031   0.0009 -3.5725 0.0004 -0.0047 -0.0014
# norm_diversity:norm_recomb  0.0031   0.0005  6.2450 0.0000  0.0021  0.0041
# ==========================================================================
#  Intercept                             0
# norm_diversity                     0.36
# norm_recomb                    0.000354
# norm_diversity:norm_recomb     4.24e-10
# dtype: float64 <F test: F=13.111844933984038, p=1.4952369021674556e-08, df_denom=2.52e+04, df_num=3>
# Serengeti, Tanzania                     Results: Generalized linear model
# ==========================================================================
# Model:                GLM                     AIC:            -57908.2563
# Link Function:        Identity                BIC:            -255258.7545
# Dependent Variable:   minor_parent_percentage Log-Likelihood: 28958.
# Date:                 2026-07-20 11:16        LL-Null:        28940.
# No. Observations:     25205                   Deviance:       148.28
# Df Model:             3                       Pearson chi2:   148.
# Df Residuals:         25201                   Scale:          0.0058840
# Method:               IRLS
# --------------------------------------------------------------------------
#                             Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# --------------------------------------------------------------------------
# Intercept                   0.0449   0.0005 84.0063 0.0000  0.0439  0.0459
# norm_diversity              0.0021   0.0006  3.4705 0.0005  0.0009  0.0032
# norm_recomb                -0.0033   0.0007 -4.8228 0.0000 -0.0046 -0.0020
# norm_diversity:norm_recomb  0.0020   0.0004  5.0305 0.0000  0.0012  0.0028
# ==========================================================================
#  Intercept                             0
# norm_diversity                 0.000519
# norm_recomb                    1.42e-06
# norm_diversity:norm_recomb     4.89e-07
# dtype: float64 <F test: F=12.116206792283828, p=6.398191209192841e-08, df_denom=2.52e+04, df_num=3>

# %%
pd.DataFrame({"Origin": o_l, "Recombination Slope": cr_l, "Diversity Slope": cd_l, "Interaction Slope": i_l,
              "Recombination p-val": rd_l, "Diversity p-val": nd_l, "Interaction p-val": id_l})
# Out:
#                    Origin  Recombination Slope  Diversity Slope  \
# 0        Selous, Tanzania             3.19e-05        -0.000171
# 1      Udzungwa, Tanzania            -0.000749          0.00186
# 2        Katavi, Tanzania             -0.00369          0.00517
# 3         Ruaha, Tanzania             -0.00493          0.00595
# 4     Tarangire, Tanzania             -0.00595        -0.000856
# 5        Arusha, Tanzania             0.000818          -0.0031
# 6    Ngorongoro, Tanzania             -0.00175          0.00149
# 7         Gombe, Tanzania             -0.00732           0.0087
# 8  Lake Manyara, Tanzania             -0.00306          0.00068
# 9     Serengeti, Tanzania             -0.00329          0.00205
#
#    Interaction Slope  Recombination p-val  Diversity p-val  Interaction p-val
# 0           3.59e-05                0.822            0.164              0.665
# 1          -6.24e-05               0.0169         8.38e-12              0.734
# 2          -0.000153             0.000822         6.14e-08              0.812
# 3            0.00133              4.7e-09         3.49e-16            0.00697
# 4            0.00458              0.00011            0.521           3.61e-07
# 5            0.00174                0.505          0.00347             0.0149
# 6            0.00209               0.0952            0.101           0.000672
# 7            0.00232             2.12e-11          4.2e-20           0.000285
# 8            0.00313             0.000354             0.36           4.24e-10
# 9            0.00201             1.42e-06         0.000519           4.89e-07

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = norm_filter.loc[norm_filter.Origin == o]
    glm_results = smf.ols(formula = "minor_parent_percentage ~ norm_diversity", data=o_div
                         ).fit()
    print(o, glm_results.summary2())
# Out:
# Selous, Tanzania                       Results: Ordinary least squares
# ============================================================================
# Model:              OLS                     Adj. R-squared:     0.000
# Dependent Variable: minor_parent_percentage AIC:                -137049.1761
# Date:               2026-07-20 11:16        BIC:                -137032.9065
# No. Observations:   25205                   Log-Likelihood:     68527.
# Df Model:           1                       F-statistic:        1.894
# Df Residuals:       25203                   Prob (F-statistic): 0.169
# R-squared:          0.000                   Scale:              0.00025472
# -------------------------------------------------------------------------------
#                    Coef.     Std.Err.       t       P>|t|      [0.025    0.975]
# -------------------------------------------------------------------------------
# Intercept          0.0016      0.0001    15.9413    0.0000     0.0014    0.0018
# norm_diversity    -0.0001      0.0001    -1.3763    0.1687    -0.0003    0.0001
# ----------------------------------------------------------------------------
# Omnibus:              40612.144        Durbin-Watson:           0.467
# Prob(Omnibus):        0.000            Jarque-Bera (JB):        18071923.353
# Skew:                 10.899           Prob(JB):                0.000
# Kurtosis:             132.355          Condition No.:           1
# ============================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Udzungwa, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.002
# Dependent Variable: minor_parent_percentage AIC:                -97058.1536
# Date:               2026-07-20 11:16        BIC:                -97041.8840
# No. Observations:   25205                   Log-Likelihood:     48531.
# Df Model:           1                       F-statistic:        39.79
# Df Residuals:       25203                   Prob (F-statistic): 2.87e-10
# R-squared:          0.002                   Scale:              0.0012449
# ------------------------------------------------------------------------------
#                    Coef.     Std.Err.       t       P>|t|     [0.025    0.975]
# ------------------------------------------------------------------------------
# Intercept          0.0105      0.0002    47.0652    0.0000    0.0100    0.0109
# norm_diversity     0.0014      0.0002     6.3083    0.0000    0.0010    0.0018
# ---------------------------------------------------------------------------
# Omnibus:               22621.233        Durbin-Watson:           0.471
# Prob(Omnibus):         0.000            Jarque-Bera (JB):        743576.667
# Skew:                  4.386            Prob(JB):                0.000
# Kurtosis:              28.121           Condition No.:           1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Katavi, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.001
# Dependent Variable: minor_parent_percentage AIC:                -33690.6474
# Date:               2026-07-20 11:16        BIC:                -33674.3778
# No. Observations:   25205                   Log-Likelihood:     16847.
# Df Model:           1                       F-statistic:        14.71
# Df Residuals:       25203                   Prob (F-statistic): 0.000125
# R-squared:          0.001                   Scale:              0.015381
# ------------------------------------------------------------------------------
#                    Coef.     Std.Err.       t       P>|t|     [0.025    0.975]
# ------------------------------------------------------------------------------
# Intercept          0.0660      0.0008    84.5378    0.0000    0.0645    0.0676
# norm_diversity     0.0030      0.0008     3.8359    0.0001    0.0015    0.0045
# ---------------------------------------------------------------------------
# Omnibus:               9331.988         Durbin-Watson:            0.337
# Prob(Omnibus):         0.000            Jarque-Bera (JB):         30180.400
# Skew:                  1.939            Prob(JB):                 0.000
# Kurtosis:              6.701            Condition No.:            1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Ruaha, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.001
# Dependent Variable: minor_parent_percentage AIC:                -47230.1136
# Date:               2026-07-20 11:16        BIC:                -47213.8440
# No. Observations:   25205                   Log-Likelihood:     23617.
# Df Model:           1                       F-statistic:        37.43
# Df Residuals:       25203                   Prob (F-statistic): 9.63e-10
# R-squared:          0.001                   Scale:              0.0089886
# ------------------------------------------------------------------------------
#                   Coef.     Std.Err.       t        P>|t|     [0.025    0.975]
# ------------------------------------------------------------------------------
# Intercept         0.0760      0.0006    127.2296    0.0000    0.0748    0.0771
# norm_diversity    0.0037      0.0006      6.1178    0.0000    0.0025    0.0048
# ---------------------------------------------------------------------------
# Omnibus:               7800.084         Durbin-Watson:            0.376
# Prob(Omnibus):         0.000            Jarque-Bera (JB):         22579.899
# Skew:                  1.638            Prob(JB):                 0.000
# Kurtosis:              6.281            Condition No.:            1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Tarangire, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.000
# Dependent Variable: minor_parent_percentage AIC:                -16849.7806
# Date:               2026-07-20 11:16        BIC:                -16833.5110
# No. Observations:   25205                   Log-Likelihood:     8426.9
# Df Model:           1                       F-statistic:        5.013
# Df Residuals:       25203                   Prob (F-statistic): 0.0252
# R-squared:          0.000                   Scale:              0.030003
# -----------------------------------------------------------------------------
#                     Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------
# Intercept           0.2254     0.0011   206.6315   0.0000    0.2233    0.2276
# norm_diversity     -0.0024     0.0011    -2.2391   0.0252   -0.0046   -0.0003
# ---------------------------------------------------------------------------
# Omnibus:                2188.315         Durbin-Watson:            0.214
# Prob(Omnibus):          0.000            Jarque-Bera (JB):         2796.755
# Skew:                   0.799            Prob(JB):                 0.000
# Kurtosis:               3.330            Condition No.:            1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Arusha, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.000
# Dependent Variable: minor_parent_percentage AIC:                -28360.8219
# Date:               2026-07-20 11:16        BIC:                -28344.5523
# No. Observations:   25205                   Log-Likelihood:     14182.
# Df Model:           1                       F-statistic:        4.989
# Df Residuals:       25203                   Prob (F-statistic): 0.0255
# R-squared:          0.000                   Scale:              0.019003
# -----------------------------------------------------------------------------
#                     Coef.    Std.Err.      t       P>|t|     [0.025    0.975]
# -----------------------------------------------------------------------------
# Intercept           0.0874     0.0009   100.6342   0.0000    0.0857    0.0891
# norm_diversity     -0.0019     0.0009    -2.2337   0.0255   -0.0036   -0.0002
# ---------------------------------------------------------------------------
# Omnibus:                10659.751        Durbin-Watson:           0.286
# Prob(Omnibus):          0.000            Jarque-Bera (JB):        47058.356
# Skew:                   2.086            Prob(JB):                0.000
# Kurtosis:               8.234            Condition No.:           1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Ngorongoro, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.000
# Dependent Variable: minor_parent_percentage AIC:                -36180.9758
# Date:               2026-07-20 11:16        BIC:                -36164.7062
# No. Observations:   25205                   Log-Likelihood:     18092.
# Df Model:           1                       F-statistic:        3.137
# Df Residuals:       25203                   Prob (F-statistic): 0.0765
# R-squared:          0.000                   Scale:              0.013934
# ------------------------------------------------------------------------------
#                   Coef.     Std.Err.       t       P>|t|      [0.025    0.975]
# ------------------------------------------------------------------------------
# Intercept         0.0677      0.0007    91.1153    0.0000     0.0663    0.0692
# norm_diversity    0.0013      0.0007     1.7712    0.0765    -0.0001    0.0028
# ---------------------------------------------------------------------------
# Omnibus:               13897.439        Durbin-Watson:           0.380
# Prob(Omnibus):         0.000            Jarque-Bera (JB):        107395.454
# Skew:                  2.602            Prob(JB):                0.000
# Kurtosis:              11.671           Condition No.:           1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Gombe, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.002
# Dependent Variable: minor_parent_percentage AIC:                -34080.3838
# Date:               2026-07-20 11:16        BIC:                -34064.1142
# No. Observations:   25205                   Log-Likelihood:     17042.
# Df Model:           1                       F-statistic:        48.98
# Df Residuals:       25203                   Prob (F-statistic): 2.65e-12
# R-squared:          0.002                   Scale:              0.015145
# ------------------------------------------------------------------------------
#                    Coef.     Std.Err.       t       P>|t|     [0.025    0.975]
# ------------------------------------------------------------------------------
# Intercept          0.0762      0.0008    98.2779    0.0000    0.0747    0.0777
# norm_diversity     0.0054      0.0008     6.9987    0.0000    0.0039    0.0069
# ---------------------------------------------------------------------------
# Omnibus:               14852.127        Durbin-Watson:           0.262
# Prob(Omnibus):         0.000            Jarque-Bera (JB):        133866.808
# Skew:                  2.771            Prob(JB):                0.000
# Kurtosis:              12.836           Condition No.:           1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Lake Manyara, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     -0.000
# Dependent Variable: minor_parent_percentage AIC:                -46390.6020
# Date:               2026-07-20 11:16        BIC:                -46374.3324
# No. Observations:   25205                   Log-Likelihood:     23197.
# Df Model:           1                       F-statistic:        0.08077
# Df Residuals:       25203                   Prob (F-statistic): 0.776
# R-squared:          0.000                   Scale:              0.0092931
# -----------------------------------------------------------------------------
#                      Coef.    Std.Err.      t       P>|t|     [0.025   0.975]
# -----------------------------------------------------------------------------
# Intercept            0.0662     0.0006   109.0905   0.0000    0.0651   0.0674
# norm_diversity       0.0002     0.0006     0.2842   0.7763   -0.0010   0.0014
# ---------------------------------------------------------------------------
# Omnibus:               14267.259        Durbin-Watson:           0.381
# Prob(Omnibus):         0.000            Jarque-Bera (JB):        128534.306
# Skew:                  2.624            Prob(JB):                0.000
# Kurtosis:              12.739           Condition No.:           1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.
# Serengeti, Tanzania                       Results: Ordinary least squares
# ===========================================================================
# Model:              OLS                     Adj. R-squared:     0.000
# Dependent Variable: minor_parent_percentage AIC:                -57879.9124
# Date:               2026-07-20 11:16        BIC:                -57863.6428
# No. Observations:   25205                   Log-Likelihood:     28942.
# Df Model:           1                       F-statistic:        3.984
# Df Residuals:       25203                   Prob (F-statistic): 0.0459
# R-squared:          0.000                   Scale:              0.0058910
# ------------------------------------------------------------------------------
#                    Coef.     Std.Err.       t       P>|t|     [0.025    0.975]
# ------------------------------------------------------------------------------
# Intercept          0.0460      0.0005    95.2504    0.0000    0.0451    0.0470
# norm_diversity     0.0010      0.0005     1.9961    0.0459    0.0000    0.0019
# ---------------------------------------------------------------------------
# Omnibus:               15219.478        Durbin-Watson:           0.386
# Prob(Omnibus):         0.000            Jarque-Bera (JB):        161756.733
# Skew:                  2.790            Prob(JB):                0.000
# Kurtosis:              14.086           Condition No.:           1
# ===========================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is
# correctly specified.

# %%
g = sns.jointplot(norm_filter.loc[(norm_filter.Origin == "Serengeti, Tanzania") &
                              #(admix_div_mean["minor_parent_percentage"] < 0.5) &
                              (norm_filter.callable_frac > 0.9)], x="norm_diversity", y="norm_recomb")
g.set_axis_labels(xlabel="Normlized Diversity", ylabel="Normalized Recombination in cM")

# %%
ser_div = admix_div_mean.loc[admix_div_mean.Origin == "Serengeti, Tanzania"].reset_index()
ser_div["tarangire_diff"] = (admix_div_mean.loc[admix_div_mean.Origin == "Serengeti, Tanzania"].minor_parent_percentage.reset_index()-admix_div_mean.loc[admix_div_mean.Origin == "Tarangire, Tanzania"].minor_parent_percentage.reset_index()).minor_parent_percentage
ser_div = ser_div.loc[(ser_div.callable_frac > 0.9)]
glm_results = smf.glm(formula = "tarangire_diff ~ diversity", data=ser_div,
                         var_weights=np.asarray(ser_div.diversity)
                         ).fit()
print(glm_results.summary(), glm_results.pvalues[1])
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:         tarangire_diff   No. Observations:                22963
# Model:                            GLM   Df Residuals:                    22961
# Model Family:                Gaussian   Df Model:                            1
# Link Function:               Identity   Scale:                      5.2296e-05
# Method:                          IRLS   Log-Likelihood:                 6567.3
# Date:                Mon, 20 Jul 2026   Deviance:                       1.2008
# Time:                        11:16:30   Pearson chi2:                     1.20
# No. Iterations:                     3   Pseudo R-squ. (CS):          0.0004459
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.1895      0.003    -56.508      0.000      -0.196      -0.183
# diversity      5.3035      1.657      3.200      0.001       2.055       8.552
# ============================================================================== 0.0013731201096991415

# %%
yellow_pops = filter_qcut_recomb.loc[filter_qcut_recomb.Origin.isin(["Katavi, Tanzania", "Ruaha, Tanzania"])]
glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity*Origin", data=yellow_pops,
                         var_weights=np.asarray(yellow_pops.diversity)
                         ).fit()
print(glm_results.summary(), glm_results.pvalues[0], glm_results.pvalues[3])
# Out:
#                     Generalized Linear Model Regression Results
# ===================================================================================
# Dep. Variable:     minor_parent_percentage   No. Observations:                50802
# Model:                                 GLM   Df Residuals:                    50798
# Model Family:                     Gaussian   Df Model:                            3
# Link Function:                    Identity   Scale:                      2.1111e-05
# Method:                               IRLS   Log-Likelihood:                 37996.
# Date:                     Mon, 20 Jul 2026   Deviance:                       1.0724
# Time:                             11:16:30   Pearson chi2:                     1.07
# No. Iterations:                          3   Pseudo R-squ. (CS):           0.002948
# Covariance Type:                 nonrobust
# =======================================================================================================
#                                           coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.0613      0.002     30.416      0.000       0.057       0.065
# Origin[T.Ruaha, Tanzania]               0.0055      0.003      1.935      0.053   -7.24e-05       0.011
# diversity                               2.8664      0.974      2.943      0.003       0.958       4.775
# diversity:Origin[T.Ruaha, Tanzania]     2.4956      1.377      1.812      0.070      -0.204       5.195
# ======================================================================================================= 3.3397659772541544e-203 0.0699712327144887

# %% [markdown]
# ChrX case

# %%
chrX_mean = mean_window_df_tanz_eth.loc[mean_window_df_tanz_eth.chrom == "all_chrX"]
chrX_mean["chrom"] = "chrX"
admix_div_chrX_all = mean_diversity.merge(chrX_mean, on=["chrom", "start"])
admix_div_chrX_all["North Percentage"] = admix_div_chrX_all.north_sum/100000
admix_div_chrX_all = admix_div_chrX_all.merge(c_r_g_df, on=["chrom", "start"])
admix_div_chrX_all["Species"] = admix_div_chrX_all.Origin.map(dict(zip(meta_data_samples_sci.Origin, meta_data_samples_sci.Species)))
# Out:
# /tmp/50076219/ipykernel_3073965/4154381476.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   chrX_mean["chrom"] = "chrX"

# %%
#Selecting the cases of interest and setting Minor Parent Ancestry

admix_div_chrX_all = admix_div_chrX_all.loc[admix_div_chrX_all.Origin.isin(origins_interest)]
admix_div_chrX_all["minor_parent_percentage"] = [x if y == ("cynocephalus") or z == "Gog Woreda, Gambella region, Ethiopia_eth_case"
                                             else 1-x for x, y, z in zip(admix_div_chrX_all["North Percentage"],
                                                                         admix_div_chrX_all["Species"],
                                                                        admix_div_chrX_all["Origin"])]
admix_div_chrX_all["local_minor_ancestry"] = [min(x, 1-x) for x in admix_div_chrX_all["North Percentage"]]
filter_callable_chrX = admix_div_chrX_all.loc[admix_div_chrX_all.callable_frac > 0.9]
filter_callable_chrX.loc[filter_callable_chrX['Origin'] == 'Gog Woreda, Gambella region, Ethiopia_eth_case', ['Origin']] = 'Gog Woreda, Ethiopia'
filter_callable_chrX["diversity"].quantile([0.005, 0.995])
# Out:
# 0.005     0.000147
# 0.995      0.00156
# Name: diversity, dtype: float64

# %% [markdown]
# Plot of difference in frequencies across the autosome and ChrX.

# %%
filter_callable_all = pd.concat([filter_callable_chrX, filter_callable])
filter_callable_all["chrom_type"] = ["autosome" if x != "chrX" else "chrX" for x in filter_callable_all.chrom]

# %%
g = sns.FacetGrid(filter_callable_all.loc[filter_callable_all.Origin.isin(["Gog Woreda, Ethiopia"])])
g.map_dataframe(sns.histplot, x="minor_parent_percentage", hue="chrom_type", hue_order=["autosome", "chrX"],
                 common_norm = False, bins=10, stat="percent") 
g.add_legend()
g.set(yscale="log")
#g.set_titles(col_template="{col_name}")
g.set(xlabel="Minor Parent Ancestry")

# %%
g = sns.FacetGrid(filter_callable_all.loc[filter_callable_all.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 4, col_order=result_order_no_gog,legend_out=True)
g.map_dataframe(sns.histplot, x="minor_parent_percentage", hue="chrom_type", hue_order=["autosome", "chrX"],
                 common_norm = False, bins=10, stat="percent") 
g.add_legend()
g.set(yscale="log")
g.set_titles(col_template="{col_name}")
g.set(xlabel="Minor Parent Ancestry")

# %%
g = sns.FacetGrid(filter_callable_all.loc[filter_callable_all.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 4, col_order=result_order_no_gog,legend_out=True)
g.map_dataframe(sns.histplot, x="minor_parent_percentage", hue="chrom_type", hue_order=["autosome", "chrX"],
                 common_norm = False, bins=10, stat="percent") 
g.add_legend()
g.set(ylim=(0, 5))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Minor Parent Ancestry")

# %%
result_order_no_gog_tarangire = [
 'Udzungwa, Tanzania',
 'Katavi, Tanzania',
 'Ruaha, Tanzania',
"Tarangire, Tanzania",
 'Arusha, Tanzania',
 'Ngorongoro, Tanzania',
 'Gombe, Tanzania',
 'Lake Manyara, Tanzania',
 'Serengeti, Tanzania']

# %%
g = sns.FacetGrid(filter_callable_all.loc[filter_callable_all.Origin.isin(result_order_no_gog_tarangire)].sort_values(by=["chrom"]), col="Origin",
                  col_wrap = 4, col_order=result_order_no_gog_tarangire)
g.map_dataframe(sns.barplot, y="minor_parent_percentage", x="chrom_type", palette=sns.color_palette(), errorbar=None) 
g.set_titles(col_template="{col_name}")
g.set(xlabel="Chromosome Type", ylabel="MPA Proportion")

# %%
filter_callable_all.loc[filter_callable_all.Origin.isin(gog)].chrom.unique()
# Out:
# array(['chrX', 'chr1', 'chr10', 'chr11', 'chr12', 'chr13', 'chr14',
#        'chr15', 'chr16', 'chr17', 'chr18', 'chr19', 'chr2', 'chr20',
#        'chr3', 'chr4', 'chr5', 'chr6', 'chr7', 'chr8', 'chr9'],
#       dtype=object)

# %%
filter_qcut_chrX = filter_callable_chrX.loc[(filter_callable_chrX.diversity >= 0.000147) & 
                                           (filter_callable_chrX.diversity <= 0.00156)]

# %%
filter_qcut.loc[filter_qcut.Origin.isin(gog)].diversity.mean(), filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)].diversity.mean()
# Out:
# (0.001711774744977684, 0.0006392304305855299)

# %%
filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)].diversity.mean()/filter_qcut.loc[filter_qcut.Origin.isin(gog)].diversity.mean()
# Out:
# 0.373431394791295

# %%
from scipy.stats import mannwhitneyu
res = mannwhitneyu(filter_qcut.loc[filter_qcut.Origin.isin(gog)].diversity*0.75,
                   filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)].diversity, alternative="greater")
print(res)
# Out:
# MannwhitneyuResult(statistic=24092456.0, pvalue=0.0)

# %%
import statsmodels.api as sm
df_l = []
for o in result_order:
    o_div = filter_qcut_chrX.loc[filter_qcut_chrX.Origin == o]
    Y = o_div["minor_parent_percentage"]
    X = o_div.diversity
    X = sm.add_constant(X)
    model = sm.OLS(Y,X)
    results = model.fit()
    print(o)
    #print(results.t_test([1, 0]))
    het_test = sm.stats.het_breuschpagan(resid=results.resid, exog_het=X)
    print(het_test)
    #print(sm.stats.diagnostic.linear_harvey_collier(results))
    df_l.append(list(het_test))
bp_df = pd.DataFrame(df_l, columns=["Lagrange Multiplier", "Lagrange Multiplier P-value", "F-statistic", "F-statistic P-value"])
bp_df["Origin"] = result_order
bp_df
# Out:
# Selous, Tanzania
# (nan, nan, nan, nan)
# Udzungwa, Tanzania
# (0.006790197284032962, 0.9343265261358384, 0.006777465041114889, 0.934403515569574)
# Katavi, Tanzania
# (1.0656116031082092, 0.3019387887721209, 1.064673979156649, 0.3023867156554727)
# Ruaha, Tanzania
# (37.64367965506844, 8.49213906613352e-10, 38.95225817751988, 6.267561580020682e-10)
# Tarangire, Tanzania
# (4.318250636224847, 0.037705666381420574, 4.327706534837256, 0.037736269042414776)
# Arusha, Tanzania
# (0.14206502209800365, 0.7062366703806164, 0.14181668451210128, 0.7065569160659287)
# Ngorongoro, Tanzania
# (0.15319566878554225, 0.6954999790389252, 0.15292947574297122, 0.6958299334622813)
# Gombe, Tanzania
# (18.189293828921258, 1.9999996378764356e-05, 18.471136100059717, 1.8835294743323086e-05)
# Lake Manyara, Tanzania
# (1.587000186238408, 0.2077552476025965, 1.5863826784619686, 0.20812070640340516)
# Serengeti, Tanzania
# (8.712076651790444, 0.0031610891048664807, 8.767541696004692, 0.0031346250447782647)
# /home/eriks/miniconda3/envs/baboondiversity/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1870: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# /home/eriks/miniconda3/envs/baboondiversity/lib/python3.8/site-packages/statsmodels/regression/linear_model.py:1781: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#    Lagrange Multiplier  Lagrange Multiplier P-value  F-statistic  \
# 0                  NaN                          NaN          NaN
# 1              0.00679                        0.934      0.00678
# 2                 1.07                        0.302         1.06
# 3                 37.6                     8.49e-10           39
# 4                 4.32                       0.0377         4.33
# 5                0.142                        0.706        0.142
# 6                0.153                        0.695        0.153
# 7                 18.2                        2e-05         18.5
# 8                 1.59                        0.208         1.59
# 9                 8.71                      0.00316         8.77
#
#    F-statistic P-value                  Origin
# 0                  NaN        Selous, Tanzania
# 1                0.934      Udzungwa, Tanzania
# 2                0.302        Katavi, Tanzania
# 3             6.27e-10         Ruaha, Tanzania
# 4               0.0377     Tarangire, Tanzania
# 5                0.707        Arusha, Tanzania
# 6                0.696    Ngorongoro, Tanzania
# 7             1.88e-05         Gombe, Tanzania
# 8                0.208  Lake Manyara, Tanzania
# 9              0.00313     Serengeti, Tanzania

# %%
filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
g = sns.FacetGrid(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 4, col_order=result_order_no_gog)
g.map_dataframe(sns.pointplot, y="minor_parent_percentage", x="Diversity Quantile", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Diversity Quantile", ylabel="Minor Parent Ancestry")
# Out:
# /tmp/50076219/ipykernel_3073965/515002999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,

# %%
filter_qcut["Diversity Quantile"] = pd.qcut(filter_qcut.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
filter_qcut["chrom_type"] = "autosome"

filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
filter_qcut_chrX["chrom_type"] = "chrX"
concat_df = pd.concat([filter_qcut, filter_qcut_chrX])

g = sns.FacetGrid(concat_df.loc[concat_df.Origin.isin(["Gog Woreda, Ethiopia"])], hue="chrom_type")
g.map_dataframe(sns.pointplot, y="minor_parent_percentage", x="Diversity Quantile", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Diversity Quantile", ylabel="Minor Parent Ancestry")
g.fig.set_figwidth(3.8)
g.fig.set_figheight(3.8)
# Out:
# /tmp/50076219/ipykernel_3073965/3625251695.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
# /tmp/50076219/ipykernel_3073965/3625251695.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_chrX["chrom_type"] = "chrX"

# %%
o_l, low_l, high_l, effect_l, effect_hl_l = [], [], [], [], []
filter_qcut_chrX["Recombination Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
for o in result_order:
    s_df = filter_qcut_chrX.loc[filter_qcut_chrX.Origin == o]
    #print(o, s_df.groupby(["Recombination Quantile"])[["minor_parent_percentage"]].mean())
    low_mean = s_df.loc[s_df["Recombination Quantile"] == "0-20"][["minor_parent_percentage"]].mean()[0]*100
    high_mean = s_df.loc[s_df["Recombination Quantile"] == "80-100"][["minor_parent_percentage"]].mean()[0]*100
    o_l.append(o)
    low_l.append(low_mean)
    high_l.append(high_mean)
    effect_l.append(high_mean/low_mean-1)

mean_quantile_df = pd.DataFrame({"Origin": o_l, "0-20 Minor Parent Percentage": low_l, 
                        "80-100 Minor Parent Percentage": high_l, "Relative Increase": effect_l})
mean_quantile_df["Absolute Increase"] = mean_quantile_df["80-100 Minor Parent Percentage"]-mean_quantile_df["0-20 Minor Parent Percentage"]
mean_quantile_df
# Out:
# /tmp/50076219/ipykernel_3073965/3187102455.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_chrX["Recombination Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
# /tmp/50076219/ipykernel_3073965/3187102455.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   effect_l.append(high_mean/low_mean-1)
#                    Origin  0-20 Minor Parent Percentage  \
# 0        Selous, Tanzania                             0
# 1      Udzungwa, Tanzania                         0.235
# 2        Katavi, Tanzania                         0.939
# 3         Ruaha, Tanzania                          1.46
# 4     Tarangire, Tanzania                          31.3
# 5        Arusha, Tanzania                           5.9
# 6    Ngorongoro, Tanzania                           6.4
# 7         Gombe, Tanzania                          4.35
# 8  Lake Manyara, Tanzania                           5.6
# 9     Serengeti, Tanzania                         0.827
#
#    80-100 Minor Parent Percentage  Relative Increase  Absolute Increase
# 0                               0                NaN                  0
# 1                            1.31               4.57               1.07
# 2                            2.09               1.22               1.15
# 3                            10.9               6.47               9.45
# 4                            23.4             -0.253              -7.94
# 5                            5.95            0.00922             0.0544
# 6                            6.36           -0.00704            -0.0451
# 7                            9.29               1.13               4.93
# 8                            6.33              0.132              0.738
# 9                            4.53               4.47                3.7

# %%
o_l, low_l, high_l, effect_l, effect_hl_l = [], [], [], [], []
filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
for o in result_order:
    s_df = filter_qcut_chrX.loc[filter_qcut_chrX.Origin == o]
    #print(o, s_df.groupby(["Diversity Quantile"])[["minor_parent_percentage"]].mean())
    low_mean = s_df.loc[s_df["Diversity Quantile"] == "0-20"][["minor_parent_percentage"]].mean()[0]*100
    high_mean = s_df.loc[s_df["Diversity Quantile"] == "80-100"][["minor_parent_percentage"]].mean()[0]*100
    o_l.append(o)
    low_l.append(low_mean)
    high_l.append(high_mean)
    effect_l.append(high_mean/low_mean)
# Out:
# /tmp/50076219/ipykernel_3073965/2844885158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
# /tmp/50076219/ipykernel_3073965/2844885158.py:14: RuntimeWarning: invalid value encountered in scalar divide
#   effect_l.append(high_mean/low_mean)

# %%
import statsmodels.formula.api as smf
import numpy as np
import pandas as pd

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut_chrX.loc[filter_qcut_chrX.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])
# Out:
# /home/eriks/miniconda3/envs/baboondiversity/lib/python3.8/site-packages/statsmodels/genmod/families/family.py:188: RuntimeWarning: invalid value encountered in divide
#   return np.sum(resid_dev * freq_weights * var_weights / scale)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[107], line 4
#       2 for o in result_order:
#       3     o_div = filter_qcut_chrX.loc[filter_qcut_chrX.Origin == o]
# ----> 4     glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=o_div,
#       5                          var_weights=np.asarray(o_div["diversity"])).fit()
#       6     print(o, glm_results.summary())
#       7     o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
#
# File ~/miniconda3/envs/baboondiversity/lib/python3.8/site-packages/statsmodels/genmod/generalized_linear_model.py:1107, in GLM.fit(self, start_params, maxiter, method, tol, scale, cov_type, cov_kwds, use_t, full_output, disp, max_start_irls, **kwargs)
#    1105     if cov_type.lower() == 'eim':
#    1106         cov_type = 'nonrobust'
# -> 1107     return self._fit_irls(start_params=start_params, maxiter=maxiter,
#    1108                           tol=tol, scale=scale, cov_type=cov_type,
#    1109                           cov_kwds=cov_kwds, use_t=use_t, **kwargs)
#    1110 else:
#    1111     self._optim_hessian = kwargs.get('optim_hessian')
#
# File ~/miniconda3/envs/baboondiversity/lib/python3.8/site-packages/statsmodels/genmod/generalized_linear_model.py:1224, in GLM._fit_irls(self, start_params, maxiter, tol, scale, cov_type, cov_kwds, use_t, **kwargs)
#    1221 dev = self.family.deviance(self.endog, mu, self.var_weights,
#    1222                            self.freq_weights, self.scale)
#    1223 if np.isnan(dev):
# -> 1224     raise ValueError("The first guess on the deviance function "
#    1225                      "returned a nan.  This could be a boundary "
#    1226                      " problem and should be reported.")
#    1228 # first guess on the deviance is assumed to be scaled by 1.
#    1229 # params are none to start, so they line up with the deviance
#    1230 history = dict(params=[np.inf, start_params], deviance=[np.inf, dev])
#
# ValueError: The first guess on the deviance function returned a nan.  This could be a boundary  problem and should be reported.

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut_chrX.loc[filter_qcut_chrX.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df

# %%
import matplotlib.ticker as ticker
g = sns.histplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)], x="diversity", )
g.set(xlabel = "Background Diversity")
g.xaxis.set_major_locator(ticker.MultipleLocator(0.00025))

# %%
filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)].diversity.mean(), filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)].diversity.median()

# %%
g = lmplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(yellows)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Yellow Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
g = lmplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(olives)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
g = lmplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(olives_with_tarangire)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Olive Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
g = lmplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)], x="diversity", y="minor_parent_percentage",
                            scatter=False, weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Gog Olive Baboons Chromosome X")
g.set(ylim=(-0.01, None))
g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
g = lmplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(["Mahale, Tanzania",
                                                           "Katavi, Tanzania",
                                                           "Issa Valley, Tanzania"])], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Kinda-like Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
g = lmplot(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(gog)], x="diversity", y="minor_parent_percentage",
                             hue="Origin", weighted=True, n_boot=1000) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Ethiopian Olives")
g.set(ylim=(-0.01, None))
g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
filter_callable_chrX["average_cM_window"].quantile([0.005, 0.995])

# %%
filter_qcut_recomb_chrX = filter_callable_chrX.loc[(filter_callable_chrX.average_cM_window >=1.96e-08) &
                                                      (filter_callable_chrX.average_cM_window <=4.15e-06)]
filter_qcut_recomb_chrX["window_cM"] = filter_qcut_recomb_chrX.average_cM_window*100000

# %%
o_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut_recomb_chrX.loc[filter_qcut_recomb_chrX.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ window_cM", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
    pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
    stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df

# %%
norm_filter_chrX = filter_qcut_chrX.loc[(filter_qcut_chrX.average_cM_window >=1.96e-08) &
                                                      (filter_qcut_chrX.average_cM_window <=4.15e-06)]
norm_filter_chrX["norm_diversity"] = (norm_filter_chrX.diversity-norm_filter_chrX.diversity.mean())/(norm_filter_chrX.diversity.std())
norm_filter_chrX["norm_recomb"] = (norm_filter_chrX.average_cM_window-norm_filter_chrX.average_cM_window.mean())/(norm_filter_chrX.average_cM_window.std())

# %%
autosome_chrX_norm = pd.concat([norm_filter, norm_filter_chrX])
autosome_chrX_norm["chrom_type"] = ["autosome" if x != "chrX" else "chrX" for x in autosome_chrX_norm.chrom]

# %%
o_l, slope_l, pval_slope_l, slope_multi, stderr_slope_l, div_l, pdiv_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = autosome_chrX_norm.loc[(autosome_chrX_norm.Origin == o)]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity * chrom_type", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[3])
    pval_slope_l.append(glm_results.pvalues[3])
    slope_multi.append(glm_results.params[3]/glm_results.params[2])
    div_l.append(glm_results.params[2]), pdiv_l.append(glm_results.pvalues[2])

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Autosome Slope": div_l, "Interaction Slope": slope_l,
                                 "Relative Increase": slope_multi, "Autosome P-value": pdiv_l,
                                 "Interaction Slope P-value": pval_slope_l
                               })
glm_diversity_df

# %%
selected_pops = ["Mahale, Tanzania","Katavi, Tanzania","Issa Valley, Tanzania"]

o_l, slope_l, pval_slope_l, slope_multi, stderr_slope_l, div_l, pdiv_l = [], [], [], [], [], [], []
for o in selected_pops:
    o_div = autosome_chrX_norm.loc[(autosome_chrX_norm.Origin == o)]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity * chrom_type", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[3])
    pval_slope_l.append(glm_results.pvalues[3])
    slope_multi.append(glm_results.params[3]/glm_results.params[2])
    div_l.append(glm_results.params[2]), pdiv_l.append(glm_results.pvalues[2])

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Autosome Slope": div_l, "Interaction Slope": slope_l,
                                 "Relative Increase": slope_multi, "Autosome P-value": pdiv_l,
                                 "Interaction Slope P-value": pval_slope_l
                               })
glm_diversity_df

# %%
g = lmplot(autosome_chrX_norm.loc[autosome_chrX_norm.Origin.isin(gog)], x="norm_diversity", y="minor_parent_percentage",
                            scatter=False, hue="chrom_type", n_boot=1000) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Normalized Diversity", title="Ethiopian Yellows")
g.set(ylim=(-0.01, None))
g._legend.set(title="Chromosome Type")
#g.set(xticks=[0, 0.0005, 0.001, 0.0015])

# %%
o_l, slope_l, pval_slope_l, slope_multi, stderr_slope_l = [], [], [], [], []
for o in result_order:
    o_div = autosome_chrX_norm.loc[autosome_chrX_norm.Origin == o]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity * chrom_type", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[3])
    pval_slope_l.append(glm_results.pvalues[3]), stderr_slope_l.append(glm_results.bse[3])
    slope_multi.append(glm_results.params[3]/glm_results.params[2])

# %%
o_l, slope_l, pval_slope_l, slope_multi, stderr_slope_l = [], [], [], [], []
for o in range(1):
    o_div = autosome_chrX_norm.loc[autosome_chrX_norm.Origin.isin(["Mahale, Tanzania", "Katavi, Tanzania"])]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity * chrom_type", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())

# %%
g = lmplot(autosome_chrX_norm.loc[autosome_chrX_norm.Origin.isin(gog)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="chrom_type", n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Gog Olive Baboons")
g.set(ylim=(-0.01, None), xlim=(None, 0.0025))
g._legend.set(title="Chromosome Type")

# %%
selected_pops = ["Mahale, Tanzania","Katavi, Tanzania","Issa Valley, Tanzania"]
g = lmplot(autosome_chrX_norm.loc[autosome_chrX_norm.Origin.isin(selected_pops)],
           x="diversity", y="minor_parent_percentage",
            scatter=False, hue="chrom_type", n_boot=1000, col="Origin", col_wrap=3,
          col_order=selected_pops, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity")
g.set(ylim=(-0.01, None), xlim=(None, 0.0025))
g.set_titles(col_template="{col_name}")
g._legend.set(title="Chromosome Type", bbox_to_anchor=(1.05, 0.5))

# %%
g = lmplot(autosome_chrX_norm.loc[autosome_chrX_norm.Origin.isin(result_order_no_gog)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="chrom_type", n_boot=1000, col="Origin", col_wrap=3, col_order=result_order_no_gog, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity")
g.set(ylim=(-0.01, None), xlim=(None, 0.0026))
g.set_titles(col_template="{col_name}")
g._legend.set(title="Chromosome Type")

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Interaction Slope": slope_l, "Relative Increase": slope_multi, "Slope P-value": pval_slope_l,
                               "Slope stderr": stderr_slope_l})
glm_diversity_df

# %% [markdown]
# Removing high freq regions.

# %%
o_l, slope_l, pval_slope_l, slope_multi, stderr_slope_l, div_l, pdiv_l = [], [], [], [], [], [], []
for o in result_order:
    o_div = autosome_chrX_norm.loc[(autosome_chrX_norm.Origin == o) & (autosome_chrX_norm.minor_parent_percentage <= 0.25)]
    glm_results = smf.glm(formula = "minor_parent_percentage ~ norm_diversity * chrom_type", data=o_div,
                         var_weights=np.asarray(o_div["diversity"])).fit()
    print(o, glm_results.summary())
    o_l.append(o), slope_l.append(glm_results.params[3])
    pval_slope_l.append(glm_results.pvalues[3])
    slope_multi.append(glm_results.params[3]/glm_results.params[2])
    div_l.append(glm_results.params[2]), pdiv_l.append(glm_results.pvalues[2])

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "Autosome Slope": div_l, "Interaction Slope": slope_l,
                                 "Relative Increase": slope_multi, "Autosome P-value": pdiv_l,
                                 "Interaction Slope P-value": pval_slope_l
                               })
glm_diversity_df

# %%
g = lmplot(autosome_chrX_norm.loc[autosome_chrX_norm.Origin.isin(result_order_no_gog) &
                                  (autosome_chrX_norm.minor_parent_percentage <= 0.25)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="chrom_type", n_boot=1000, col="Origin", col_wrap=3, col_order=result_order_no_gog, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity")
g.set(ylim=(-0.01, None), xlim=(None, 0.0026))
g.set_titles(col_template="{col_name}")
g._legend.set(title="Chromosome Type")

# %% [markdown]
# Quantiles of Admixture/Diversity

# %%
filter_qcut_chrX["ancestry"] = ["Pure Major" if x <= 0.1 else "Pure Minor" if x >= 0.9
                        else "Mixed" for x in filter_qcut_chrX["minor_parent_percentage"]]
g = sns.FacetGrid(filter_qcut_chrX.loc[filter_qcut_chrX.Origin.isin(result_order)], col="Origin",
                  col_wrap = 4, col_order=result_order)
g.map_dataframe(sns.boxplot, x="diversity", y="ancestry", fliersize=0)
g.set_titles(col_template="{col_name}")
g.set(xlabel="Background Diversity")

# %%
filter_qcut["ancestry"] = ["Pure Major" if x <= 0.1 else "Pure Minor" if x >= 0.9
                        else "Mixed" for x in filter_qcut["minor_parent_percentage"]]
g = sns.FacetGrid(filter_qcut.loc[filter_qcut.Origin.isin(result_order)], col="Origin",
                  col_wrap = 4, col_order=result_order)
g.map_dataframe(sns.boxplot, x="diversity", y="ancestry", fliersize=0)
g.set_titles(col_template="{col_name}")
g.set(xlabel="Background Diversity")

# %%
hama_df = filter_qcut.loc[(filter_qcut.Origin == "Gog Woreda, Ethiopia")][["chrom", "start", "ancestry"]]
hama_df_add = filter_qcut.merge(hama_df, on=["chrom", "start"])
hama_df_chrX = filter_qcut_chrX.loc[(filter_qcut_chrX.Origin == "Gog Woreda, Ethiopia")][["chrom", "start", "ancestry"]]
hama_df_add_chrX = filter_qcut_chrX.merge(hama_df_chrX, on=["chrom", "start"])

# %%
g = sns.FacetGrid(hama_df_add.loc[hama_df_add.Origin.isin(result_order)], col="Origin",
                  col_wrap = 4, col_order=result_order)
g.map_dataframe(sns.boxplot, x="minor_parent_percentage", y="ancestry_y", fliersize=0)
g.set_titles(col_template="{col_name}")
g.set(xlabel="Admixture")

# %%
for o in result_order:
    o_df = hama_df_add.loc[hama_df_add.Origin == o]
    print(o, o_df.groupby(["ancestry_y"])["minor_parent_percentage"].mean(),
         o_df.value_counts(["ancestry_y"]))
    print(mannwhitneyu(o_df.loc[o_df.ancestry_y == "Pure Minor"].minor_parent_percentage,
                   o_df.loc[o_df.ancestry_y == "Mixed"].minor_parent_percentage))

# %%
for o in result_order:
    o_df = hama_df_add_chrX.loc[hama_df_add_chrX.Origin == o]
    print(o, o_df.groupby(["ancestry_y"])["minor_parent_percentage"].mean(),
         o_df.value_counts(["ancestry_y"]))
    print(mannwhitneyu(o_df.loc[o_df.ancestry_y == "Pure Minor"].minor_parent_percentage,
                   o_df.loc[o_df.ancestry_y == "Mixed"].minor_parent_percentage))

# %% [markdown]
# Merged quintiles

# %%
filter_qcut_chrX["Diversity Quintile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
filter_qcut_chrX["Chromosome Type"] = "chrX"

filter_qcut["Diversity Quintile"] = pd.qcut(filter_qcut.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
filter_qcut["Chromosome Type"] = "autosome"
filter_qcut_both = pd.concat([filter_qcut, filter_qcut_chrX])
g = sns.FacetGrid(filter_qcut_both.loc[filter_qcut_both.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 3, col_order=result_order_no_gog, hue="Chromosome Type")
g.map_dataframe(sns.pointplot, y="minor_parent_percentage", x="Diversity Quantile", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Diversity Quintile", ylabel="Minor Parent Ancestry")

# %%
filter_qcut_chrX["Diversity Quintile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
filter_qcut_chrX["Chromosome Type"] = "chrX"

filter_qcut["Diversity Quintile"] = pd.qcut(filter_qcut.diversity, 5,
                                                       labels=["0-20","20-40",
                                                              "40-60","60-80",
                                                              "80-100"])
filter_qcut["Chromosome Type"] = "autosome"
filter_qcut_both = pd.concat([filter_qcut, filter_qcut_chrX])
g = sns.FacetGrid(filter_qcut_both.loc[filter_qcut_both.Origin.isin(["Mahale, Tanzania", "Katavi, Tanzania",
                                                                     "Issa Valley, Tanzania"])], col="Origin",
                  col_wrap = 3, col_order=result_order_no_gog, hue="Chromosome Type")
g.map_dataframe(sns.pointplot, y="minor_parent_percentage", x="Diversity Quantile", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Diversity Quintile", ylabel="Minor Parent Ancestry")

# %%
mean_window_df_tanz_eth = window_df_tanz_eth.groupby(["chrom", "Origin", "individual", "start", "end"])[["north_sum"]].mean().reset_index()
mean_window_df_tanz = window_df_tanz.groupby(["chrom", "Origin", "individual", "start", "end"])[["north_sum"]].mean().reset_index()
admix_div_mean_ind = mean_diversity.merge(mean_window_df_tanz_eth, on=["chrom", "start"])
admix_div_mean_ind["Species"] = admix_div_mean_ind.Origin.map(dict(zip(meta_data_samples_sci.Origin, meta_data_samples_sci.Species)))
admix_div_mean_ind = admix_div_mean_ind.merge(c_r_g_df, on=["chrom", "start"])
admix_div_mean_ind["North Percentage"] = admix_div_mean_ind.north_sum/100000

# %%
admix_div_mean_ind = admix_div_mean_ind.loc[admix_div_mean_ind.Origin.isin(origins_interest)]
admix_div_mean_ind["minor_parent_percentage"] = [x if y == ("cynocephalus") or z == "Gog Woreda, Gambella region, Ethiopia_eth_case"
                                             else 1-x for x, y, z in zip(admix_div_mean_ind["North Percentage"],
                                                                         admix_div_mean_ind["Species"],
                                                                        admix_div_mean_ind["Origin"])]
admix_div_mean_ind["local_minor_ancestry"] = [min(x, 1-x) for x in admix_div_mean_ind["North Percentage"]]

# %%
filter_callable_ind = admix_div_mean_ind.loc[admix_div_mean_ind.callable_frac > 0.75]
filter_qcut_ind = filter_callable_ind.loc[(filter_callable_ind.diversity >= 0.000513) &
                                 (filter_callable_ind.diversity <= 0.00408)]

# %%
o_l, id_l, slope_l, intercept_l, pval_slope_l, pval_intercept_l, stderr_slope_l, stderr_intercept_l = [], [], [], [], [], [], [], []
for o in result_order:
    o_div = filter_qcut_ind.loc[(filter_qcut_ind.Origin == o)]
    for i in o_div.individual.unique():
        i_df = o_div.loc[o_div.individual == i]
        glm_results = smf.glm(formula = "minor_parent_percentage ~ diversity", data=i_df,
                         var_weights=np.asarray(i_df["diversity"])).fit()
        print(o, i, glm_results.summary())
        o_l.append(o), id_l.append(i)
        slope_l.append(glm_results.params[1]), intercept_l.append(glm_results.params[0])
        pval_slope_l.append(glm_results.pvalues[1]), pval_intercept_l.append(glm_results.pvalues[0])
        stderr_slope_l.append(glm_results.bse[1]), stderr_intercept_l.append(glm_results.bse[0])

# %%
glm_diversity_df = pd.DataFrame({"Origin": o_l, "individual": id_l, "Intercept": intercept_l, "Slope": slope_l, 
                                 "Intercept P-value": pval_intercept_l, "Slope P-value": pval_slope_l,
                                "Intercept stderr": stderr_intercept_l, "Slope stderr": stderr_slope_l})
glm_diversity_df

# %%
sns.histplot(data=glm_diversity_df.loc[glm_diversity_df.Origin == "Serengeti, Tanzania"], x="Slope")

# %%
glm_diversity_df.loc[glm_diversity_df.Origin == "Serengeti, Tanzania"]

# %%
g = lmplot(filter_qcut_ind.loc[filter_qcut_ind.Origin.isin(["Ruaha, Tanzania"])], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="individual", ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Yellow Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=np.arange(0.0005, 0.004, 0.001))

# %%
g = lmplot(admix_div_mean_ind.loc[admix_div_mean_ind.Origin.isin(yellows)], x="diversity", y="minor_parent_percentage",
                            scatter=False, hue="Origin", weighted=True, n_boot=1000, ci=99.5) #Additional bootstraps makes it take long
g.set(ylabel="Minor Parent Ancestry Proportion", xlabel="Background Diversity", title="Tanzanian Yellow Baboons")
g.set(ylim=(-0.01, None))
g.set(xticks=np.arange(0.0005, 0.004, 0.001))

# %% [markdown]
# Admixture per chromosome investigation

# %%
ind_df = window_df_tanz_eth.groupby(["individual", "chrom", "Origin", "start", "end"])[["north_sum"]].mean().reset_index()
ind_df_div = mean_diversity.merge(ind_df, on=["chrom", "start"])
ind_df_div = ind_df_div.merge(c_r_g_df, on=["chrom", "start"])
ind_df_div["North Percentage"] = ind_df_div.north_sum/100000
ind_df_div["Species"] = ind_df_div.Origin.map(dict(zip(meta_data_samples_sci.Origin, meta_data_samples_sci.Species)))

#Selecting the cases of interest and setting Minor Parent Ancestry

ind_df_div = ind_df_div.loc[ind_df_div.Origin.isin(origins_interest)]
ind_df_div["minor_parent_percentage"] = [x if y == ("cynocephalus") or z == "Gog Woreda, Gambella region, Ethiopia_eth_case"
                                             else 1-x for x, y, z in zip(ind_df_div["North Percentage"],
                                                                         ind_df_div["Species"],
                                                                        ind_df_div["Origin"])]
ind_df_div = ind_df_div.loc[ind_df_div.callable_frac > 0.75]

# %%
o_l, low_l, high_l, effect_l, admix_l, chr_l, ind_l = [], [], [], [], [], [], []
#filter_qcut_chrX["Diversity Quantile"] = pd.qcut(filter_qcut_chrX.diversity, 5,
#                                                       labels=["0-20","20-40",
#                                                              "40-60","60-80",
#                                                              "80-100"])

for o in ind_df_div.Origin.unique():
    print(o)
    for c in ind_df_div.chrom.unique():
        print(c)
        for i in ind_df_div.loc[(ind_df_div.Origin == o) & (ind_df_div.chrom == c)].individual.unique():
            i_s_df = ind_df_div.loc[(ind_df_div.individual == i) & (ind_df_div.chrom == c)]
            #print(i)
            o_l.append(o), ind_l.append(i), chr_l.append(c)
            i_s_df["Diversity Quantile"] = pd.qcut(i_s_df.diversity, 2,
                                                       labels=["0-50", "50-100"])
            low_mean = i_s_df.loc[i_s_df["Diversity Quantile"] == "0-50"][["minor_parent_percentage"]].mean()[0]*100
            high_mean = i_s_df.loc[i_s_df["Diversity Quantile"] == "50-100"][["minor_parent_percentage"]].mean()[0]*100
            low_l.append(low_mean)
            high_l.append(high_mean)
            effect_l.append(high_mean/low_mean)
            admix_l.append(i_s_df.minor_parent_percentage.mean())

# %%
admix_df = pd.DataFrame({"Origin": o_l, "individual": ind_l, "chrom": chr_l, "Low Diversity Quantile": low_l,
              "High Diversity Quantile": high_l, "Relative Difference": effect_l, "Mean_Admixture": admix_l})
admix_df["Absolute_Difference"] = admix_df["High Diversity Quantile"]-admix_df["Low Diversity Quantile"]
admix_df["Concentration"] = admix_df["High Diversity Quantile"]/admix_df.Mean_Admixture*0.5

# %%
sns.lmplot(admix_df.loc[admix_df.Origin == "Ruaha, Tanzania"],
           x="Mean_Admixture", y="Concentration")

# %%
admix_df["Mean Admixture Bin"] = pd.cut(admix_df.Mean_Admixture, [0, 0.02, 0.04, 0.06,
                                                                  0.08, 0.1, 0.2, 1])
g = sns.FacetGrid(admix_df.loc[admix_df.Origin.isin(result_order_no_gog)], col="Origin",
                  col_wrap = 3, col_order=result_order_no_gog)
g.map_dataframe(sns.stripplot, y="Mean Admixture Bin", x="Concentration", alpha=.1, color="grey")
g.map_dataframe(sns.pointplot, y="Mean Admixture Bin", x="Concentration", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
g.set(xlim=(25, 75))
g.set_titles(col_template="{col_name}")
axes = g.axes.flatten()
for ax in g.axes.flat:
    ax.axvline(x=50, color='r', linestyle=':')
g.set(xlabel="MPA Concentration", ylabel="Autosome Admixture Bin")

# %%
admix_df["Mean Admixture Bin"] = pd.cut(admix_df.Mean_Admixture, [0, 0.02, 0.04, 0.06,
                                                                  0.08, 0.1, 1])
admix_df["Species"] = admix_df.Origin.map(dict(zip(meta_data_samples_sci.Origin, meta_data_samples_sci.Species)))
g = sns.FacetGrid(admix_df.loc[admix_df.Origin.isin(result_order_no_gog)], col="Species",
                  col_wrap = 2)
g.map_dataframe(sns.pointplot, y="Mean Admixture Bin", x="Concentration", 
                linestyles="none", capsize=.3, errorbar=("ci", 95), scale = 0.6)
#g.map_dataframe(sns.stripplot, x="minor_parent_percentage", y="Diversity Quantile", alpha=0.05)
#g.set(xlim=(0, 0.25))
g.set_titles(col_template="{col_name}")
g.set(xlabel="Absolute Difference", ylabel="Mean Minor Parent Ancestry")

# %%
glm_results = smf.glm(formula = "Absolute_Difference ~ Mean_Admixture+I(Mean_Admixture**2)",
                      data=admix_df.loc[admix_df.Origin == "Ruaha, Tanzania"]).fit()
print(glm_results.summary())

# %%
glm_results = smf.glm(formula = "Absolute_Difference ~ Mean_Admixture", data=admix_df).fit()
print(glm_results.summary())
